# %%
import pandas as pd
import re

# %%
def predicting_txt_to_dataframe(path):    
    with open(path, 'r') as f:
        txt = str(f.read())
        txt_list = txt.split('\n')
    row_list = list()
    tmp_list = list()
    for row in txt_list:
        if row == '--------------------':
            tmp_list[0] = tmp_list[0].replace('article_id:', '')
            tmp_list[0] = int(tmp_list[0])
            row_list.append(tmp_list)
            tmp_list = list()
            continue
        if len(row) > 0:
            tmp_list.append(row)
    df = pd.DataFrame(row_list, columns=['article_id','text'])
    return df

# %%
df = predicting_txt_to_dataframe('/home/Danny/AI-CUP-2020/datasets/stage5/test.txt')
df
# Out:
#      article_id                                               text
# 0             0  醫師：最近人有沒有什麼不舒服？民眾：沒有。醫師：沒有喔。我們本來說要月，年底才打對不對？民眾...
# 1             1  醫師：要去上課嗎？民眾：沒有。這學期已經開始不上課了。醫師：啊今天的，呃，應該是昨天的抽血。...
# 2             2  醫師：後來那個吃藥沒有問題對不對？民眾：沒有。醫師：诶？你是打針的？民眾：對。醫師：阿身上有...
# 3             3  民眾：我自己昨天開始，一天吃一次一粒。醫師：一次一粒，減半量還好？民眾：阿可是……減到今天早...
# 4             4  醫師：喔，啊嘉明最近還好嗎？民眾：ＯＫ。醫師：啊今年的流感打了嗎？民眾：還沒。醫師：那我們今...
# ..          ...                                                ...
# 154         154  醫師：這個月還好嗎？民眾：就……醫師：這個月有去碰嗎？民眾：沒有，不去碰的時候就會覺得慾望非...
# 155         155  醫師：啊這個月還好嗎？民眾：還好啊。醫師：好，所以你反正天天吃啦齁？民眾：對。醫師：好，我們...
# 156         156  醫師：好那所以總之就是好，所以總之反正，總之就是……這這……就是反正你剩下的藥你就是……就是...
# 157         157  醫師：好，所以第一個月吃藥的狀況怎麼樣？民眾：嗯，吃藥狀況喔？醫師：嗯。民眾：就是吃了，一開...
# 158         158  個管師：你上次有領了啊哈。民眾：我知道啊。個管師：你怎麼就是用後不理了呢？民眾：不是……醫師...
#
# [159 rows x 2 columns]

# %%
contact_df = pd.read_csv('ground_truth/contact.csv')
contact_list = contact_df['entity_text'].tolist()
contact_list
# Out:
# ['臉書',
#  'Grindr',
#  'Hornet',
#  'tinder',
#  'LINE',
#  'ＬＩＮＥ',
#  'line',
#  'Line',
#  '0945678393',
#  '0978936572',
#  'e-mail',
#  'badboyisme',
#  '0983333786',
#  'www.prep.gov',
#  'MAIL',
#  'EMAIL']

# %%
def get_contact(article_id, text, target):
    output_str = str()
    entity_type = 'contact'
    source = 'dictionary_ground_truth'
    for match in re.finditer(target, text, re.IGNORECASE):
        output_str += '{}\t{}\t{}\t{}\t{}\t{}\n'.format(article_id, match.start(), match.end(), match.group(), entity_type, source)
    return output_str

# %%
output_str = '{}\t{}\t{}\t{}\t{}\t{}\n'.format('article_id', 'start_position', 'end_position', 'entity_text', 'entity_type', 'source')
for contact in contact_list:
    for article_id, text in zip(df['article_id'], df['text']):
        output_str += get_contact(article_id, text, contact)
print(output_str)
# Out:
# article_id	start_position	end_position	entity_text	entity_type	source
# 62	1400	1402	臉書	contact	dictionary_ground_truth
# 24	425	429	line	contact	dictionary_ground_truth
# 24	465	469	line	contact	dictionary_ground_truth
# 50	2410	2414	LINE	contact	dictionary_ground_truth
# 64	925	929	line	contact	dictionary_ground_truth
# 104	521	525	LINE	contact	dictionary_ground_truth
# 115	1252	1256	LINE	contact	dictionary_ground_truth
# 116	1301	1305	LINE	contact	dictionary_ground_truth
# 122	1844	1848	line	contact	dictionary_ground_truth
# 124	466	470	Line	contact	dictionary_ground_truth
# 127	709	713	line	contact	dictionary_ground_truth
# 131	219	223	line	contact	dictionary_ground_truth
# 131	349	353	line	contact	dictionary_ground_truth
# 131	1154	1158	line	contact	dictionary_ground_truth
# 133	322	326	LINE	contact	dictionary_ground_truth
# 133	1012	1016	LINE	contact	dictionary_ground_truth
# 136	465	469	LINE	contact	dictionary_ground_truth
# 136	528	532	LINE	contact	dictionary_ground_truth
# 136	776	780	LINE	contact	dictionary_ground_truth
# 137	1399	1403	Line	contact	dictionary_ground_truth
# 138	1444	1448	LINE	contact	dictionary_ground_truth
# 138	1563	1567	LINE	contact	dictionary_ground_truth
# 142	486	490	LINE	contact	dictionary_ground_truth
# 148	1092	1096	line	contact	dictionary_ground_truth
# 157	2923	2927	LINE	contact	dictionary_ground_truth
# 132	1420	1424	ＬＩＮＥ	contact	dictionary_ground_truth
# 155	2549	2553	ＬＩＮＥ	contact	dictionary_ground_truth
# 24	425	429	line	contact	dictionary_ground_truth
# 24	465	469	line	contact	dictionary_ground_truth
# 50	2410	2414	LINE	contact	dictionary_ground_truth
# 64	925	929	line	contact	dictionary_ground_truth
# 104	521	525	LINE	contact	dictionary_ground_truth
# 115	1252	1256	LINE	contact	dictionary_ground_truth
# 116	1301	1305	LINE	contact	dictionary_ground_truth
# 122	1844	1848	line	contact	dictionary_ground_truth
# 124	466	470	Line	contact	dictionary_ground_truth
# 127	709	713	line	contact	dictionary_ground_truth
# 131	219	223	line	contact	dictionary_ground_truth
# 131	349	353	line	contact	dictionary_ground_truth
# 131	1154	1158	line	contact	dictionary_ground_truth
# 133	322	326	LINE	contact	dictionary_ground_truth
# 133	1012	1016	LINE	contact	dictionary_ground_truth
# 136	465	469	LINE	contact	dictionary_ground_truth
# 136	528	532	LINE	contact	dictionary_ground_truth
# 136	776	780	LINE	contact	dictionary_ground_truth
# 137	1399	1403	Line	contact	dictionary_ground_truth
# 138	1444	1448	LINE	contact	dictionary_ground_truth
# 138	1563	1567	LINE	contact	dictionary_ground_truth
# 142	486	490	LINE	contact	dictionary_ground_truth
# 148	1092	1096	line	contact	dictionary_ground_truth
# 157	2923	2927	LINE	contact	dictionary_ground_truth
# 24	425	429	line	contact	dictionary_ground_truth
# 24	465	469	line	contact	dictionary_ground_truth
# 50	2410	2414	LINE	contact	dictionary_ground_truth
# 64	925	929	line	contact	dictionary_ground_truth
# 104	521	525	LINE	contact	dictionary_ground_truth
# 115	1252	1256	LINE	contact	dictionary_ground_truth
# 116	1301	1305	LINE	contact	dictionary_ground_truth
# 122	1844	1848	line	contact	dictionary_ground_truth
# 124	466	470	Line	contact	dictionary_ground_truth
# 127	709	713	line	contact	dictionary_ground_truth
# 131	219	223	line	contact	dictionary_ground_truth
# 131	349	353	line	contact	dictionary_ground_truth
# 131	1154	1158	line	contact	dictionary_ground_truth
# 133	322	326	LINE	contact	dictionary_ground_truth
# 133	1012	1016	LINE	contact	dictionary_ground_truth
# 136	465	469	LINE	contact	dictionary_ground_truth
# 136	528	532	LINE	contact	dictionary_ground_truth
# 136	776	780	LINE	contact	dictionary_ground_truth
# 137	1399	1403	Line	contact	dictionary_ground_truth
# 138	1444	1448	LINE	contact	dictionary_ground_truth
# 138	1563	1567	LINE	contact	dictionary_ground_truth
# 142	486	490	LINE	contact	dictionary_ground_truth
# 148	1092	1096	line	contact	dictionary_ground_truth
# 157	2923	2927	LINE	contact	dictionary_ground_truth
# 135	699	703	mail	contact	dictionary_ground_truth
# 135	710	714	mail	contact	dictionary_ground_truth
# 142	457	461	MAIL	contact	dictionary_ground_truth
# 142	456	461	EMAIL	contact	dictionary_ground_truth

# %%
with open('dictionary.tsv', 'w', encoding='utf-8') as f:
    f.write(output_str)

# %%
df = pd.read_csv('dictionary.tsv', sep='\t')
df
# Out:
#     article_id  start_position  end_position entity_text entity_type  \
# 0           62            1400          1402          臉書     contact
# 1           24             425           429        line     contact
# 2           24             465           469        line     contact
# 3           50            2410          2414        LINE     contact
# 4           64             925           929        line     contact
# ..         ...             ...           ...         ...         ...
# 74         157            2923          2927        LINE     contact
# 75         135             699           703        mail     contact
# 76         135             710           714        mail     contact
# 77         142             457           461        MAIL     contact
# 78         142             456           461       EMAIL     contact
#
#                      source
# 0   dictionary_ground_truth
# 1   dictionary_ground_truth
# 2   dictionary_ground_truth
# 3   dictionary_ground_truth
# 4   dictionary_ground_truth
# ..                      ...
# 74  dictionary_ground_truth
# 75  dictionary_ground_truth
# 76  dictionary_ground_truth
# 77  dictionary_ground_truth
# 78  dictionary_ground_truth
#
# [79 rows x 6 columns]

# %%
df = df.sort_values(by=['article_id', 'start_position'])
df
# Out:
#     article_id  start_position  end_position entity_text entity_type  \
# 1           24             425           429        line     contact
# 27          24             425           429        line     contact
# 51          24             425           429        line     contact
# 2           24             465           469        line     contact
# 28          24             465           469        line     contact
# ..         ...             ...           ...         ...         ...
# 73         148            1092          1096        line     contact
# 26         155            2549          2553        ＬＩＮＥ     contact
# 24         157            2923          2927        LINE     contact
# 50         157            2923          2927        LINE     contact
# 74         157            2923          2927        LINE     contact
#
#                      source
# 1   dictionary_ground_truth
# 27  dictionary_ground_truth
# 51  dictionary_ground_truth
# 2   dictionary_ground_truth
# 28  dictionary_ground_truth
# ..                      ...
# 73  dictionary_ground_truth
# 26  dictionary_ground_truth
# 24  dictionary_ground_truth
# 50  dictionary_ground_truth
# 74  dictionary_ground_truth
#
# [79 rows x 6 columns]

# %%
df = df.drop_duplicates()
df
# Out:
#     article_id  start_position  end_position entity_text entity_type  \
# 0           62            1400          1402          臉書     contact
# 1           24             425           429        line     contact
# 2           24             465           469        line     contact
# 3           50            2410          2414        LINE     contact
# 4           64             925           929        line     contact
# 5          104             521           525        LINE     contact
# 6          115            1252          1256        LINE     contact
# 7          116            1301          1305        LINE     contact
# 8          122            1844          1848        line     contact
# 9          124             466           470        Line     contact
# 10         127             709           713        line     contact
# 11         131             219           223        line     contact
# 12         131             349           353        line     contact
# 13         131            1154          1158        line     contact
# 14         133             322           326        LINE     contact
# 15         133            1012          1016        LINE     contact
# 16         136             465           469        LINE     contact
# 17         136             528           532        LINE     contact
# 18         136             776           780        LINE     contact
# 19         137            1399          1403        Line     contact
# 20         138            1444          1448        LINE     contact
# 21         138            1563          1567        LINE     contact
# 22         142             486           490        LINE     contact
# 23         148            1092          1096        line     contact
# 24         157            2923          2927        LINE     contact
# 25         132            1420          1424        ＬＩＮＥ     contact
# 26         155            2549          2553        ＬＩＮＥ     contact
# 75         135             699           703        mail     contact
# 76         135             710           714        mail     contact
# 77         142             457           461        MAIL     contact
# 78         142             456           461       EMAIL     contact
#
#                      source
# 0   dictionary_ground_truth
# 1   dictionary_ground_truth
# 2   dictionary_ground_truth
# 3   dictionary_ground_truth
# 4   dictionary_ground_truth
# 5   dictionary_ground_truth
# 6   dictionary_ground_truth
# 7   dictionary_ground_truth
# 8   dictionary_ground_truth
# 9   dictionary_ground_truth
# 10  dictionary_ground_truth
# 11  dictionary_ground_truth
# 12  dictionary_ground_truth
# 13  dictionary_ground_truth
# 14  dictionary_ground_truth
# 15  dictionary_ground_truth
# 16  dictionary_ground_truth
# 17  dictionary_ground_truth
# 18  dictionary_ground_truth
# 19  dictionary_ground_truth
# 20  dictionary_ground_truth
# 21  dictionary_ground_truth
# 22  dictionary_ground_truth
# 23  dictionary_ground_truth
# 24  dictionary_ground_truth
# 25  dictionary_ground_truth
# 26  dictionary_ground_truth
# 75  dictionary_ground_truth
# 76  dictionary_ground_truth
# 77  dictionary_ground_truth
# 78  dictionary_ground_truth
