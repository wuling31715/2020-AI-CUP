# %%
import re
import pandas as pd
from matplotlib import pyplot as plt

# %%
# 不用儲存article_id, 轉成list
def training_txt_to_list(path):
    with open(path, 'r') as f:
        txt = str(f.read())
    txt_list = txt.split('\n')
    text_label_list = list()
    tmp = list()
    for line in txt_list:
        if line == '--------------------':
            text_label_list.append(tmp)
            tmp = list()
            continue
        if line == '':
            continue
        tmp.append(line)
    x = list()
    y = list()
    for text_label in text_label_list:
        text = text_label[0]
        label = text_label[2:]
        label_list = ['O' for i in range(len(text))]
        for i in label:
            entity = i.split('\t')
            if int(entity[1]) > int(entity[2]):
                continue
            b = int(entity[1])
            label_list[b] = 'B-{}'.format(entity[-1])
            for j in range(int(entity[1])+1, int(entity[2])):
                label_list[j] = 'I-{}'.format(entity[-1])
        for i, j in enumerate(text):
            if j == '，' or j == '。' or j == '？':
                label_list[i] = j
                
        text_list = re.split('\uff0c|\u3002|\uff1f', text)
        for sentence in text_list:
            x.append([i for i in sentence])
        x = x[:-1]
            
        sentence = list()
        for i in label_list:
            if i == '，' or i == '。' or i == '？':
                y.append(sentence)
                sentence = list()
            else:
                sentence.append(i)
                
    return [x, y]

# %%
x1, y1 = training_txt_to_list('/home/Danny/AI-CUP-2020/datasets/stage1/SampleData_deid.txt')
x2, y2 = training_txt_to_list('/home/Danny/AI-CUP-2020/datasets/stage2/train_1_update.txt')
x4, y4 = training_txt_to_list('/home/Danny/AI-CUP-2020/datasets/stage4/train_2.txt')

# %%
x = x1 + x2 + x4
y = y1 + y2 + y4
print(len(x))
print(len(y))
# Out:
# 76162
# 76162

# %%
df = pd.DataFrame({'x': x, 'y': y})

# %%
df['x'] = df['x'].apply(lambda row : str(row))
df['y'] = df['y'].apply(lambda row : str(row))
df = df.drop_duplicates()
df['x'] = df['x'].apply(lambda row : eval(row))
df['y'] = df['y'].apply(lambda row : eval(row))
df
# Out:
#                                                 x  \
# 0                  [醫, 師, ：, 你, 有, 做, 超, 音, 波, 嘛]
# 1                           [那, 我, 們, 來, 看, 報, 告]
# 2                        [有, 些, 部, 分, 有, 紅, 字, 耶]
# 3                  [民, 眾, ：, 紅, 字, 是, 甚, 麼, 意, 思]
# 4            [醫, 師, ：, 就, 是, 肝, 功, 能, 有, 比, 較, 高]
# ...                                           ...
# 75713                       [醫, 師, ：, 7, 4, 0, 3]
# 75714     [醫, 師, ：, 6, 6, 6, 0, 8, 9, 7, 4, 0, 3]
# 75716              [護, 理, 師, ：, 6, 6, 6, 0, 9, 8]
# 75717              [醫, 師, ：, 0, 9, 8, 7, 4, 0, 3]
# 76102  [好, 像, 是, 那, 時, 候, 跑, 完, 6, 0, 0, 0, 公, 尺]
#
#                                                        y
# 0                         [O, O, O, O, O, O, O, O, O, O]
# 1                                  [O, O, O, O, O, O, O]
# 2                               [O, O, O, O, O, O, O, O]
# 3                         [O, O, O, O, O, O, O, O, O, O]
# 4                   [O, O, O, O, O, O, O, O, O, O, O, O]
# ...                                                  ...
# 75713                  [O, O, O, B-ID, I-ID, I-ID, I-ID]
# 75714  [O, O, O, B-ID, I-ID, I-ID, I-ID, I-ID, I-ID, ...
# 75716   [O, O, O, O, B-ID, I-ID, I-ID, I-ID, I-ID, I-ID]
# 75717  [O, O, O, B-ID, I-ID, I-ID, I-ID, I-ID, I-ID, ...
# 76102         [O, O, O, O, O, O, O, O, O, O, O, O, O, O]
#
# [31521 rows x 2 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#                                                 x  \
# 0                  [醫, 師, ：, 你, 有, 做, 超, 音, 波, 嘛]
# 1                           [那, 我, 們, 來, 看, 報, 告]
# 2                        [有, 些, 部, 分, 有, 紅, 字, 耶]
# 3                  [民, 眾, ：, 紅, 字, 是, 甚, 麼, 意, 思]
# 4            [醫, 師, ：, 就, 是, 肝, 功, 能, 有, 比, 較, 高]
# ...                                           ...
# 31516                       [醫, 師, ：, 7, 4, 0, 3]
# 31517     [醫, 師, ：, 6, 6, 6, 0, 8, 9, 7, 4, 0, 3]
# 31518              [護, 理, 師, ：, 6, 6, 6, 0, 9, 8]
# 31519              [醫, 師, ：, 0, 9, 8, 7, 4, 0, 3]
# 31520  [好, 像, 是, 那, 時, 候, 跑, 完, 6, 0, 0, 0, 公, 尺]
#
#                                                        y
# 0                         [O, O, O, O, O, O, O, O, O, O]
# 1                                  [O, O, O, O, O, O, O]
# 2                               [O, O, O, O, O, O, O, O]
# 3                         [O, O, O, O, O, O, O, O, O, O]
# 4                   [O, O, O, O, O, O, O, O, O, O, O, O]
# ...                                                  ...
# 31516                  [O, O, O, B-ID, I-ID, I-ID, I-ID]
# 31517  [O, O, O, B-ID, I-ID, I-ID, I-ID, I-ID, I-ID, ...
# 31518   [O, O, O, O, B-ID, I-ID, I-ID, I-ID, I-ID, I-ID]
# 31519  [O, O, O, B-ID, I-ID, I-ID, I-ID, I-ID, I-ID, ...
# 31520         [O, O, O, O, O, O, O, O, O, O, O, O, O, O]
#
# [31521 rows x 2 columns]

# %%
def find_contain_entity_rows(labels):
    dic_temp = {}
    dummy = 0
    for label in labels:
        dic_temp[label] = dummy
    #if len(dic_temp) > 1:
    #    return True
    if 'B-profession' in dic_temp:
        return True
    else:
        return False
df['flag'] = df['y'].apply(lambda l:find_contain_entity_rows(l))

# %%
df_entity = df[df['flag'] == True]

# %%
df_entity = df_entity.reset_index(drop=True)

# %%
df_entity = df_entity.drop(index=[2,3,5,11,12,20,21,33,34,35])
df_entity= df_entity.reset_index(drop=True)

# %%
df_entity
# Out:
#                                                     x  \
# 0                            [民, 眾, ：, 我, 打, 撲, 克, 牌]
# 1                            [民, 眾, ：, 我, 做, 保, 險, 的]
# 2                               [民, 眾, ：, 因, 為, 公, 務]
# 3                      [醫, 師, ：, 你, 是, 教, 授, 是, 不, 是]
# 4                                           [當, 教, 授]
# 5                               [你, 是, 肝, 膽, 科, 是, 嗎]
# 6                      [民, 眾, ：, 然, 後, 再, 轉, 肝, 膽, 科]
# 7                      [民, 眾, ：, 如, 果, 是, 肝, 膽, 的, 話]
# 8                                  [民, 衆, ：, 工, 程, 師]
# 9                      [那, 個, 時, 候, 是, 白, 天, 送, 報, 紙]
# 10                                    [晚, 上, 飲, 料, 店]
# 11                           [現, 在, 是, 白, 天, 送, 牛, 奶]
# 12                                    [晚, 上, 水, 餃, 店]
# 13   [民, 眾, ：, 對, 啊, 因, 為, 我, 水, 餃, 店, 禮, 拜, 三, 休, 息]
# 14               [醫, 師, ：, 哦, 你, 們, 是, 哪, 一, 家, 水, 餃]
# 15            [民, 眾, ：, 對, 阿, 因, 為, 我, 爸, 在, 做, 工, 地]
# 16                              [民, 眾, ：, 就, 是, 工, 地]
# 17                           [醫, 師, A, ：, 工, 地, 哈, 哈]
# 18      [台, 灣, 有, 做, …, …, 那, 種, 專, 門, 做, 工, 地, 的, 喔]
# 19                              [民, 眾, ：, 做, 矽, 晶, 圓]
# 20                                       [做, 矽, 晶, 圓]
# 21                                    [我, 在, 外, 資, 的]
# 22                                             [外, 資]
# 23                     [因, 為, 我, 現, 在, 當, 替, 代, 役, 了]
# 24  [嗯, 哼, 你, 說, 替, 代, 役, 的, 制, 度, 還, 是, 他, 職, 務, ...
# 25                        [民, 眾, ：, 替, 代, 役, 的, 制, 度]
# 26                                          [金, 融, 業]
# 27                           [個, 管, 師, ：, 銀, 行, 員, 嗎]
# 28                                       [消, 防, 員, 啊]
# 29                              [個, 管, 師, ：, 消, 防, 員]
# 30                        [因, 為, 我, 是, 還, 是, 老, 師, 嘛]
#
#                                                     y  flag
# 0   [O, O, O, O, B-profession, I-profession, I-pro...  True
# 1      [O, O, O, O, O, B-profession, I-profession, O]  True
# 2         [O, O, O, O, O, B-profession, I-profession]  True
# 3   [O, O, O, O, O, B-profession, I-profession, O,...  True
# 4                     [O, B-profession, I-profession]  True
# 5   [O, O, B-profession, I-profession, I-professio...  True
# 6   [O, O, O, O, O, O, O, B-profession, I-professi...  True
# 7   [O, O, O, O, O, O, B-profession, I-profession,...  True
# 8   [O, O, O, B-profession, I-profession, I-profes...  True
# 9   [O, O, O, O, O, B-time, I-time, B-profession, ...  True
# 10  [B-time, I-time, B-profession, I-profession, I...  True
# 11  [O, O, O, B-time, I-time, B-profession, I-prof...  True
# 12  [B-time, I-time, B-profession, I-profession, I...  True
# 13  [O, O, O, O, O, O, O, O, B-profession, I-profe...  True
# 14  [O, O, O, O, O, O, O, O, O, O, B-profession, I...  True
# 15  [O, O, O, O, O, O, O, O, B-family, O, O, B-pro...  True
# 16        [O, O, O, O, O, B-profession, I-profession]  True
# 17     [O, O, O, O, B-profession, I-profession, O, O]  True
# 18  [O, O, O, O, O, O, O, O, O, O, O, B-profession...  True
# 19  [O, O, O, O, B-profession, I-profession, I-pro...  True
# 20      [O, B-profession, I-profession, I-profession]  True
# 21              [O, O, B-profession, I-profession, O]  True
# 22                       [B-profession, I-profession]  True
# 23  [O, O, O, O, O, O, B-profession, I-profession,...  True
# 24  [O, O, O, O, B-profession, I-profession, I-pro...  True
# 25  [O, O, O, B-profession, I-profession, I-profes...  True
# 26         [B-profession, I-profession, I-profession]  True
# 27  [O, O, O, O, B-profession, I-profession, I-pro...  True
# 28      [B-profession, I-profession, I-profession, O]  True
# 29  [O, O, O, O, B-profession, I-profession, I-pro...  True
# 30  [O, O, O, O, O, O, B-profession, I-profession, O]  True

# %%
profession_df = pd.read_csv('../dictionary/online/profession.csv')

# %%
aug_df = pd.DataFrame([],columns=['x','y'])
aug_df
# Out:
# Empty DataFrame
# Columns: [x, y]
# Index: []

# %%
for index, row in df_entity.iterrows():
    entity_start_pos = 0
    entity_end_pos = -1
    start_flag = False
    for i in range(len(row['y'])):
        if row['y'][i] == 'B-profession':
            entity_start_pos = i
            start_flag = True
        elif row['y'][i] == 'O' and start_flag == True:
            entity_end_pos = i
            break
        else:
            continue
    for entity in profession_df['entity_text']:
        sentence = []
        labels = []
        count = 0
        for i in range(entity_start_pos):
            sentence.append(row['x'][i])
            labels.append('O')
        sentence.append(entity[0])
        labels.append('B-profession')
        for i in range(1,len(entity)):
            sentence.append(entity[i])
            labels.append('I-profession')
        if entity_end_pos != -1:
            for i in range(entity_end_pos,len(row['x'])):
                sentence.append(row['x'][i])
                labels.append('O')
        #print(sentence)
        #print(labels)
        if len(sentence) != len(labels):
            print('Wrong')
        aug_df = aug_df.append({'x':sentence,'y':labels},ignore_index=True)

# %%
aug_df
# Out:
#                                              x  \
# 0                     [民, 眾, ：, 我, 打, 撲, 克, 牌]
# 1                           [民, 眾, ：, 我, 保, 險]
# 2               [民, 眾, ：, 我, G, o, o, g, l, e]
# 3                           [民, 眾, ：, 我, 公, 務]
# 4                           [民, 眾, ：, 我, 教, 授]
# ...                                        ...
# 34560        [因, 為, 我, 是, 還, 是, 馬, 術, 人, 員, 嘛]
# 34561  [因, 為, 我, 是, 還, 是, 特, 技, 表, 演, 人, 員, 嘛]
# 34562        [因, 為, 我, 是, 還, 是, 駕, 駛, 人, 員, 嘛]
# 34563        [因, 為, 我, 是, 還, 是, 賽, 車, 人, 員, 嘛]
# 34564        [因, 為, 我, 是, 還, 是, 跳, 傘, 人, 員, 嘛]
#
#                                                        y
# 0      [O, O, O, O, B-profession, I-profession, I-pro...
# 1               [O, O, O, O, B-profession, I-profession]
# 2      [O, O, O, O, B-profession, I-profession, I-pro...
# 3               [O, O, O, O, B-profession, I-profession]
# 4               [O, O, O, O, B-profession, I-profession]
# ...                                                  ...
# 34560  [O, O, O, O, O, O, B-profession, I-profession,...
# 34561  [O, O, O, O, O, O, B-profession, I-profession,...
# 34562  [O, O, O, O, O, O, B-profession, I-profession,...
# 34563  [O, O, O, O, O, O, B-profession, I-profession,...
# 34564  [O, O, O, O, O, O, B-profession, I-profession,...
#
# [34565 rows x 2 columns]

# %%
aug_df = aug_df.sample(500)
aug_df = aug_df.reset_index(drop=True)
aug_df
# Out:
#                                            x  \
# 0                                  [做, 液, 化]
# 1       [民, 眾, ：, 然, 後, 再, 轉, 貨, 櫃, 車, 司, 機]
# 2                      [你, 是, 製, 圖, 員, 是, 嗎]
# 3    [醫, 師, ：, 哦, 你, 們, 是, 哪, 一, 家, 食, 品, 商]
# 4                      [民, 眾, ：, 做, 矽, 晶, 圓]
# ..                                       ...
# 495  [那, 個, 時, 候, 是, 白, 天, 釣, 具, 製, 造, 工, 人]
# 496        [因, 為, 我, 是, 還, 是, 網, 球, 球, 員, 嘛]
# 497     [醫, 師, ：, 你, 是, 採, 椰, 子, 工, 是, 不, 是]
# 498                    [安, 養, 院, 工, 作, 人, 員]
# 499                    [我, 在, 駕, 駛, 人, 員, 的]
#
#                                                      y
# 0                      [O, B-profession, I-profession]
# 1    [O, O, O, O, O, O, O, B-profession, I-professi...
# 2    [O, O, B-profession, I-profession, I-professio...
# 3    [O, O, O, O, O, O, O, O, O, O, B-profession, I...
# 4    [O, O, O, O, B-profession, I-profession, I-pro...
# ..                                                 ...
# 495  [O, O, O, O, O, O, O, B-profession, I-professi...
# 496  [O, O, O, O, O, O, B-profession, I-profession,...
# 497  [O, O, O, O, O, B-profession, I-profession, I-...
# 498  [B-profession, I-profession, I-profession, I-p...
# 499  [O, O, B-profession, I-profession, I-professio...
#
# [500 rows x 2 columns]

# %%
aug_df.to_csv('../datasets/profession.csv',index=False)
