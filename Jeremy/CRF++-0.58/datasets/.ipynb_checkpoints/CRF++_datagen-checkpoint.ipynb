# %%
import os

# %%
data_path = './all_train.data'

# %%
with open(data_path, 'r', encoding='utf-8') as f:
        data=f.readlines()#.encode('utf-8').decode('utf-8-sig')

        
if (os.path.isfile('./crf++_all_train.data')):
        os.remove('./crf++_all_train.data')        
outputfile = open('./crf++_all_train.data', 'a', encoding= 'utf-8')

for string in data:
    if string[0] == '。':
        outputfile.write(string)
        outputfile.write('\n')
    elif string[0] == '\n':
        pass
    else:
        outputfile.write(string)

# %%
f.close()

# %%
outputfile.close()

# %%
with open('./crf++_all_train.data', 'r', encoding='utf-8') as f:
        data=f.readlines()#.encode('utf-8').decode('utf-8-sig')
num = 0
for i in range(len(data)-1):
    try:
        if data[i][0] == '。' and data[i+1][0] != '\n':
            num+=1
    except(IndexError):
        print(i)

num
# Out:
# 0

# %%
data[-10:]
# Out:
# ['對 O\n',
#  '抗 O\n',
#  '這 O\n',
#  '樣 O\n',
#  '子 O\n',
#  '， O\n',
#  'o O\n',
#  'k O\n',
#  '。 O\n',
#  '\n']

# %%
len(data)
# Out:
# 450184

# %%
data_path = './develop2.data'

# %%
with open(data_path, 'r', encoding='utf-8') as f:
        data=f.readlines()#.encode('utf-8').decode('utf-8-sig')

print(len(data))
if (os.path.isfile('./crf++_develop2.data')):
        os.remove('./crf++_develop2.data')        
outputfile = open('./crf++_develop2.data', 'a', encoding= 'utf-8')

for string in data:
    if string[0] == '。':
        outputfile.write(string)
        outputfile.write('\n')
    elif string[0] == '\n':
        pass
    else:
        outputfile.write(string)
f.close()
outputfile.close()
# Out:
# 147146

# %%
data[-10:]
# Out:
# ['沒 O\n',
#  '有 O\n',
#  '。 O\n',
#  '個 O\n',
#  '管 O\n',
#  '師 O\n',
#  '： O\n',
#  '好 O\n',
#  '。 O\n',
#  '\n']

# %%
with open('./crf++_develop2.data', 'r', encoding='utf-8') as f:
        data=f.readlines()#.encode('utf-8').decode('utf-8-sig')
num = 0
for i in range(len(data)-1):
    try:
        if data[i][0] == '。' and data[i+1][0] != '\n':
            num+=1
    except(IndexError):
        print(i)
f.close()
num
# Out:
# 0

# %%
data[-10:]
# Out:
# ['有\n', '。\n', '\n', '個\n', '管\n', '師\n', '：\n', '好\n', '。\n', '\n']

# %%
def loadInputFile(path):
    testingset = list()  # store trainingset [content,content,...]
    with open(path, 'r', encoding='utf8') as f:
        file_text=f.read().encode('utf-8').decode('utf-8-sig')
    datas=file_text.split('\n\n--------------------\n\n')[:-1]
    for data in datas:
        data=data.split('\n')
        content=data[1]
        testingset.append(content)
    
    return testingset

# %%
def CRFFormatTestData(testingset, path):
    if (os.path.isfile(path)):
        os.remove(path)
    outputfile = open(path, 'a', encoding= 'utf-8')
    for article_id in range(len(testingset)):
        token = list(testingset[article_id][0:len(testingset[article_id])])
        for token_idx in range(len(token)):
            output_str = token[token_idx] + ' ' + 'O' +'\n'
            outputfile.write(output_str)
        output_str = '\n'
        outputfile.write(output_str)
        if article_id%10 == 0:
            print('Total complete articles:', article_id)
        
    outputfile.close()

# %%
data_path='./development_2.txt'
testingset = loadInputFile(data_path)
len(testingset)
testingset[0]
# Out:
# '醫師：這個要電腦看才有辦法，這是嚴重或一般的。民眾：這是沒關係啦。醫師：沒關係齁。民眾：他一定要有說，這樣才有辦法。醫師：是是多謝你。民眾：沒關係。醫師：這樣，你過去是有得糖尿病嘛？民眾：有。醫師：啊出院後還有再發燒或是？民眾：欸出院是沒有啦。醫師：沒有啦齁。民眾：啊，有感覺人齁。醫師：嘿。民眾：比較沒沒有像以前那樣。醫師：嘿。民眾：全部都沒有力啦。醫師：齁。民眾：啊現在比較有力了啦，不知道是那一天，說我貧血齁。醫師：稍微貧血。民眾：啊幫我輸血進來。醫師：他有幫你輸血喔？民眾：感覺這樣比較。家屬：他有給他輸25的。民眾：是感覺精神啦。醫師：李醫生。家屬：他就說他貧血。醫師：有幫你輸一袋了齁。家屬：嘿，輸一袋。醫師：輸一袋。民眾：那個25。醫師：25。家屬：一包小包的。醫師：啊你排尿有比較好嗎？排尿的那個？家屬：哦他。民眾：變成說我晚上齁，我都要吃睡眠的。醫師：要吃睡眠的。民眾：啊我都差不多11點吃睡到差不多4點。醫師：是。民眾：開始起來一小時起來一次到天亮，都沒有停喔。醫師：頻尿欸喔。家屬：沒有。民眾：沒有，廁所。醫師：廁所。民眾：啊如果。家屬：他的腳齁，他的腳。醫師：水腫齁。家屬：在水腫欸，他那個藥吃太多，你幫他看一下。民眾：以前是沒有啦。醫師：以前是沒有啦。家屬：都沒有。醫師：好。民眾：啊現在有水腫。醫師：現在有水腫齁，好。民眾：啊我嚇一跳，我就沒吃睡眠的。醫師：沒吃睡眠的，好那我幫你聽一下，來。民眾：睡到11點多就都沒有睡了啊。醫師：最近沒感冒的現象啦齁。民眾：這兩天都沒有。醫師：啊有發燒嗎？民眾：欸，有時候會稍微冷冷的，但是摸起來是沒有算發燒啦。醫師：沒有算發燒。家屬：主要是肚子脹氣，現在比較沒有肚子脹氣了齁？民眾：我都吃得飽。家屬：不是吃得飽。民眾：有啦，比較沒有肚子脹氣，比較消了。醫師：比較消了喔，我們來按一下肚子一下，有在吃糖尿病的藥嗎？家屬：有。民眾：有。家屬：他就多他很會脹氣，非常會脹氣，晚上都會吐。醫師：肚子會痛嗎？家屬：他那天說。民眾：壓下去會痛痛的。醫師：是左邊還是右邊。民眾：右邊這裡。醫師：右邊這裡。民眾：這種痛的感覺是，像硬壓下去在痛。醫師：硬壓下去在痛。民眾：對對對。醫師：啊走路啦，平常時候不會痛啦齁。民眾：嗯嗯嗯嗯。醫師：啊我聽後背看看齁。民眾：走路是不會啦。醫師：走路是不會啊，脊椎這邊，脊椎這邊，這邊會痛嗎？民眾：不會。醫師：
# ...

# %%
CRFFormatTestData(testingset, './develop2.data')
# Out:
# Total complete articles: 0
# Total complete articles: 10
# Total complete articles: 20
# Total complete articles: 30
# Total complete articles: 40
# Total complete articles: 50
# Total complete articles: 60

# %%
f = open('./result')

# %%
results = f.readlines()

# %%
test_split_string = '禮\tO\tB-time\n'

test_split_string.split('\tO\t')[1].strip('\n')
# Out:
# 'B-time'

# %%
pred = []
num=0
for string in results:
    try:
        if string != '\n':
            pred.append(string.split('\tO\t')[1].strip('\n'))
            if string.split('\tO\t')[1].strip('\n') != 'O':
                print(string.split('\tO\t')[1].strip('\n'))
                num+=1
    except(IndexError):
        print(string)
print(num)
print(len(pred))
# Out:
# B-time
# I-time
# I-time
# B-time
# I-time
# B-time
# I-time
# I-time
# B-time
# I-time
# B-time
# I-time
# I-time
# I-time
# B-time
# I-time
# I-time
# I-time
# I-time
# B-name
# I-name
# I-name
# B-time
# I-time
# I-time
# I-time
# B-time
# I-time
# B-med_exam
# I-med_exam
# B-time
# I-time
# I-time
# I-time
# B-time
# I-time
# I-time
# I-time
# B-time
# I-time
# I-time
# B-time
# I-time
# I-time
# B-time
# I-time
# I-time
# B-time
# I-time
# B-time
# I-time
# B-time
# I-time
# I-time
# I-time
# B-time
# I-time
# I-time
# I-time
# B-time
# I-time
# I-time
# I-time
# B-time
# I-time
# I-time
# B-name
# I-name
# I-name
# B-time
# I-time
# I-time
# B-time
# I-time
# I-time
# B-name
# I-name
# I-name
# B-name
# I-name
# I-name
# B-name
# I-name
# I-name
# B-name
# I-name
# I-name
# B-name
# I-name
# I-name
# B-name
# I-name
# I-name
# B-time
# I-time
# B-time
# I-time
# B-time
# I-time
# B-time
# I-time
# B-time
# I-time
# I-time
# B-time
# I-time
# B-money
# I-money
# I-money
# ...

# %%
y_pred
# Out:
# ['O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
# ...

# %%
def CRFFormatTestData(testingset, path):
    if (os.path.isfile(path)):
        os.remove(path)
    outputfile = open(path, 'a', encoding= 'utf-8')
    for article_id in range(len(testingset)):
        token = list(testingset[article_id][0:len(testingset[article_id])])
        for token_idx in range(len(token)):
            output_str = token[token_idx] +'\n'
            outputfile.write(output_str)
        output_str = '\n'
        outputfile.write(output_str)
        if article_id%10 == 0:
            print('Total complete articles:', article_id)
        
    outputfile.close()

# %%
data_path='./development_2.txt'
testingset = loadInputFile(data_path)
len(testingset)
testingset[0]
# Out:
# '醫師：這個要電腦看才有辦法，這是嚴重或一般的。民眾：這是沒關係啦。醫師：沒關係齁。民眾：他一定要有說，這樣才有辦法。醫師：是是多謝你。民眾：沒關係。醫師：這樣，你過去是有得糖尿病嘛？民眾：有。醫師：啊出院後還有再發燒或是？民眾：欸出院是沒有啦。醫師：沒有啦齁。民眾：啊，有感覺人齁。醫師：嘿。民眾：比較沒沒有像以前那樣。醫師：嘿。民眾：全部都沒有力啦。醫師：齁。民眾：啊現在比較有力了啦，不知道是那一天，說我貧血齁。醫師：稍微貧血。民眾：啊幫我輸血進來。醫師：他有幫你輸血喔？民眾：感覺這樣比較。家屬：他有給他輸25的。民眾：是感覺精神啦。醫師：李醫生。家屬：他就說他貧血。醫師：有幫你輸一袋了齁。家屬：嘿，輸一袋。醫師：輸一袋。民眾：那個25。醫師：25。家屬：一包小包的。醫師：啊你排尿有比較好嗎？排尿的那個？家屬：哦他。民眾：變成說我晚上齁，我都要吃睡眠的。醫師：要吃睡眠的。民眾：啊我都差不多11點吃睡到差不多4點。醫師：是。民眾：開始起來一小時起來一次到天亮，都沒有停喔。醫師：頻尿欸喔。家屬：沒有。民眾：沒有，廁所。醫師：廁所。民眾：啊如果。家屬：他的腳齁，他的腳。醫師：水腫齁。家屬：在水腫欸，他那個藥吃太多，你幫他看一下。民眾：以前是沒有啦。醫師：以前是沒有啦。家屬：都沒有。醫師：好。民眾：啊現在有水腫。醫師：現在有水腫齁，好。民眾：啊我嚇一跳，我就沒吃睡眠的。醫師：沒吃睡眠的，好那我幫你聽一下，來。民眾：睡到11點多就都沒有睡了啊。醫師：最近沒感冒的現象啦齁。民眾：這兩天都沒有。醫師：啊有發燒嗎？民眾：欸，有時候會稍微冷冷的，但是摸起來是沒有算發燒啦。醫師：沒有算發燒。家屬：主要是肚子脹氣，現在比較沒有肚子脹氣了齁？民眾：我都吃得飽。家屬：不是吃得飽。民眾：有啦，比較沒有肚子脹氣，比較消了。醫師：比較消了喔，我們來按一下肚子一下，有在吃糖尿病的藥嗎？家屬：有。民眾：有。家屬：他就多他很會脹氣，非常會脹氣，晚上都會吐。醫師：肚子會痛嗎？家屬：他那天說。民眾：壓下去會痛痛的。醫師：是左邊還是右邊。民眾：右邊這裡。醫師：右邊這裡。民眾：這種痛的感覺是，像硬壓下去在痛。醫師：硬壓下去在痛。民眾：對對對。醫師：啊走路啦，平常時候不會痛啦齁。民眾：嗯嗯嗯嗯。醫師：啊我聽後背看看齁。民眾：走路是不會啦。醫師：走路是不會啊，脊椎這邊，脊椎這邊，這邊會痛嗎？民眾：不會。醫師：
# ...

# %%
CRFFormatTestData(testingset, './develop2_output.data')
# Out:
# Total complete articles: 0
# Total complete articles: 10
# Total complete articles: 20
# Total complete articles: 30
# Total complete articles: 40
# Total complete articles: 50
# Total complete articles: 60

# %%
def TestDataset(data_path):
    with open(data_path, 'r', encoding='utf-8') as f:
        data=f.readlines()#.encode('utf-8').decode('utf-8-sig')
    data_list, data_list_tmp = list(), list()
    article_id_list=list()
    idx=0
    for row in data:
        data_tuple = tuple()
        if row == '\n':
            article_id_list.append(idx)
            idx+=1
            data_list.append(data_list_tmp)
            data_list_tmp = []
        else:
            row = row.strip('\n').split(' ')
            data_tuple = (row[0])
            data_list_tmp.append(data_tuple)
    if len(data_list_tmp) != 0:
        data_list.append(data_list_tmp)
    
    # here we random split data into training dataset and testing dataset
    # but you should take `development data` or `test data` as testing data
    # At that time, you could just delete this line, 
    # and generate data_list of `train data` and data_list of `development/test data` by this function
    
    return data_list, article_id_list

# %%
test_data_list, testdata_article_id_list = TestDataset('./develop2_output.data')
# Out:
# --------------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-189-7eb9c0ac351f> in <module>
# ----> 1 test_data_list, testdata_article_id_list = TestDataset('./develop2_output.data')
#
# <ipython-input-188-cea1fc1aaed8> in TestDataset(data_path)
#       2     with open(data_path, 'r', encoding='utf-8') as f:
#       3         data=f.readlines()#.encode('utf-8').decode('utf-8-sig')
# ----> 4     data_list, data_list_tmp = list(), list()
#       5     article_id_list=list()
#       6     idx=0
#
# TypeError: 'list' object is not callable

# %%
output="article_id\tstart_position\tend_position\tentity_text\tentity_type\n"
num = 0
for test_id in range(len(y_pred)):
    pos=0
    start_pos=None
    end_pos=None
    entity_text=None
    entity_type=None
    for pred_id in range(len(y_pred[test_id])):
        if y_pred[test_id][pred_id][0]=='B':
            start_pos=pos
            entity_type=y_pred[test_id][pred_id][2:]
            print(entity_type)
            num+=1
        elif start_pos is not None and y_pred[test_id][pred_id][0]=='I' and pred_id+1 == len(y_pred[test_id]):
            end_pos=pos
            entity_text=''.join([test_data_list[test_id][position][0] for position in range(start_pos,end_pos+1)])
            line=str(testdata_article_id_list[test_id])+'\t'+str(start_pos)+'\t'+str(end_pos)+'\t'+entity_text+'\t'+entity_type
            output+=line+'\n'                                                                                 
        elif start_pos is not None and y_pred[test_id][pred_id][0]=='I' and y_pred[test_id][pred_id+1][0]=='O':
            end_pos=pos
            entity_text=''.join([test_data_list[test_id][position][0] for position in range(start_pos,end_pos+1)])
            line=str(testdata_article_id_list[test_id])+'\t'+str(start_pos)+'\t'+str(end_pos)+'\t'+entity_text+'\t'+entity_type
            output+=line+'\n'
        pos+=1     
        
num
# Out:
# time
# time
# time
# time
# time
# time
# name
# time
# time
# med_exam
# time
# time
# time
# time
# time
# time
# time
# time
# time
# time
# time
# name
# time
# time
# name
# name
# name
# name
# name
# name
# time
# time
# time
# time
# time
# time
# money
# time
# time
# money
# contact
# time
# time
# time
# time
# time
# time
# time
# time
# time
# med_exam
# name
# name
# time
# time
# time
# time
# time
# time
# time
# time
# time
# time
# time
# time
# name
# name
# name
# time
# med_exam
# med_exam
# time
# time
# time
# time
# name
# contact
# name
# time
# 79

# %%
output_path='./crf++_output.tsv'
with open(output_path,'w',encoding='utf-8') as f:
    f.write(output)
num = 0
for c in output:
    if c == '\n':
        num+=1
print(output)

print(num)
# Out:
# article_id	start_position	end_position	entity_text	entity_type
# 0	2332	2334	禮拜一	time
# 2	980	981	兩天	time
# 3	265	267	16號	time
# 3	609	610	一年	time
# 3	2250	2253	106年	time
# 4	7	11	6月14號	time
# 4	880	882	林醫師	name
# 5	2437	2440	6月6號	time
# 9	35	36	五月	time
# 10	71	72	74	med_exam
# 10	262	265	四個禮拜	time
# 10	537	540	十月六號	time
# 11	1233	1235	兩個月	time
# 14	476	478	2個月	time
# 14	621	623	這個月	time
# 14	662	663	4月	time
# 14	1396	1397	9月	time
# 14	1400	1403	9月20	time
# 16	235	238	六個禮拜	time
# 16	257	260	六個禮拜	time
# 21	1107	1109	一個月	time
# 22	6	8	王醫師	name
# 22	981	983	四個月	time
# 22	989	991	四個月	time
# 22	2736	2738	王醫師	name
# 23	6	8	王醫師	name
# 23	57	59	王醫師	name
# 23	576	578	王醫師	name
# 23	636	638	王醫師	name
# 23	1756	1758	王醫師	name
# 26	15	16	5月	time
# 28	30	31	一年	time
# 29	215	216	一年	time
# 31	1804	1805	今天	time
# 32	2211	2213	三個月	time
# 34	2830	2831	半年	time
# 34	2946	2950	1000塊	money
# 34	4425	4426	早上	time
# 34	4495	4497	禮拜五	time
# 35	4854	4862	500塊和600塊	money
# 36	78	81	Line	contact
# ...

# %%
# Out:
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O
# ...

# %%
num
# Out:
# 262

# %%
len(y_pred)
# Out:
# 147076

# %%
length = 0
for sen in test_data_list:
    length+=len(sen)

# %%
length
# Out:
# 147076

# %%
y_pred = []
length = 0
for a_id in range(len(test_data_list)):
    if a_id == 0:
        temp = pred[0:len(test_data_list[0])]
        y_pred.append(temp)
        length+=len(test_data_list[0])
    else:
        temp = pred[length:length+len(test_data_list[a_id])]
        y_pred.append(temp)
        length+=len(test_data_list[a_id])

# %%
temp = pred[1000:len(test_data_list[5])]

# %%
length = 0
for sen in y_pred:
    length+=len(sen)

# %%
length
# Out:
# 147076

# %%
len(y_pred)
# Out:
# 70
