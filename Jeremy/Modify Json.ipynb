# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('../ensemble/ai_cup_80-158.json',lines=True)

# %%
df
# Out:
#                                                  text  \
# 0   醫師：看起來有比較胖一點，有沒有？民眾：我也不知道。護士每天都唸。家屬：要減肥。醫師：要減肥...
# 1   民眾：這……這兩、三個禮拜有……後面有凸一個東西。醫師：嗯，我看一下。民眾：好。醫師：你說有...
# 2   民眾：有比較好。醫師：有比較好吼。民眾：阿只是那個還沒退掉。醫師：這邊好像比較好。民眾：還沒...
# 3   民眾：痾，這個禮拜，痾，可能又感染了，不知道。醫師：是。民眾：鼻涕更嚴重。醫師：鼻涕更嚴重。...
# 4   民眾：他那一天回去之後……醫師：說好像有，那個居家護理師有跟我講說，吃下去……民眾：還是過敏...
# ..                                                ...
# 75  醫師：這個月還好嗎？民眾：就……醫師：這個月有去碰嗎？民眾：沒有，不去碰的時候就會覺得慾望非...
# 76  醫師：啊這個月還好嗎？民眾：還好啊。醫師：好，所以你反正天天吃啦齁？民眾：對。醫師：好，我們...
# 77  醫師：好那所以總之就是好，所以總之反正，總之就是……這這……就是反正你剩下的藥你就是……就是...
# 78  醫師：好，所以第一個月吃藥的狀況怎麼樣？民眾：嗯，吃藥狀況喔？醫師：嗯。民眾：就是吃了，一開...
# 79  個管師：你上次有領了啊哈。民眾：我知道啊。個管師：你怎麼就是用後不理了呢？民眾：不是……醫師...
#
#                                                labels  \
# 0   [[101, 105, time], [284, 287, name], [330, 334...
# 1   [[6, 13, time], [61, 67, time], [251, 256, tim...
# 2   [[60, 62, time], [77, 79, time], [102, 104, ti...
# 3   [[5, 9, time], [479, 482, time], [486, 489, ti...
# ...

# %%
df.drop('metadata', axis=1, inplace=True)

# %%
df
# Out:
#                                                  text  \
# 0   醫師：看起來有比較胖一點，有沒有？民眾：我也不知道。護士每天都唸。家屬：要減肥。醫師：要減肥...
# 1   民眾：這……這兩、三個禮拜有……後面有凸一個東西。醫師：嗯，我看一下。民眾：好。醫師：你說有...
# 2   民眾：有比較好。醫師：有比較好吼。民眾：阿只是那個還沒退掉。醫師：這邊好像比較好。民眾：還沒...
# 3   民眾：痾，這個禮拜，痾，可能又感染了，不知道。醫師：是。民眾：鼻涕更嚴重。醫師：鼻涕更嚴重。...
# 4   民眾：他那一天回去之後……醫師：說好像有，那個居家護理師有跟我講說，吃下去……民眾：還是過敏...
# ..                                                ...
# 75  醫師：這個月還好嗎？民眾：就……醫師：這個月有去碰嗎？民眾：沒有，不去碰的時候就會覺得慾望非...
# 76  醫師：啊這個月還好嗎？民眾：還好啊。醫師：好，所以你反正天天吃啦齁？民眾：對。醫師：好，我們...
# 77  醫師：好那所以總之就是好，所以總之反正，總之就是……這這……就是反正你剩下的藥你就是……就是...
# 78  醫師：好，所以第一個月吃藥的狀況怎麼樣？民眾：嗯，吃藥狀況喔？醫師：嗯。民眾：就是吃了，一開...
# 79  個管師：你上次有領了啊哈。民眾：我知道啊。個管師：你怎麼就是用後不理了呢？民眾：不是……醫師...
#
#                                                labels
# 0   [[101, 105, time], [284, 287, name], [330, 334...
# 1   [[6, 13, time], [61, 67, time], [251, 256, tim...
# 2   [[60, 62, time], [77, 79, time], [102, 104, ti...
# 3   [[5, 9, time], [479, 482, time], [486, 489, ti...
# ...

# %%
pos_start_dict = {}
pos_end_dict = {}
entity_dict = {}
type_dict = {}
final_df = pd.DataFrame()
for idx, row in df.iterrows():
    for label in row['labels']:
        print(type(label[0]))
        temp_df = pd.DataFrame({'article_id':79+idx, 'start_position':label[0], 'end_position':label[1], 'entity_text':row['text'][label[0]:label[1]], 'entity_type':label[2]}
                               ,index=[0])
        final_df = pd.concat([final_df,temp_df])
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
final_df.reset_index(drop=True,inplace=True)

# %%
final_df
# Out:
#       article_id  start_position  end_position entity_text entity_type
# 0             79             101           105        半個小時        time
# 1             79             284           287         曹醫師        name
# 2             79             330           334        39.5    med_exam
# 3             79             356           358          22    med_exam
# 4             79             405           409        三、四點        time
# ...          ...             ...           ...         ...         ...
# 2377         158            1143          1145          今天        time
# 2378         158            1199          1201          小安        name
# 2379         158            1353          1355          今天        time
# 2380         158            1380          1390  A124699678          ID
# 2381         158            1489          1491          明年        time
#
# [2382 rows x 5 columns]

# %%
final_df.to_csv('../ensemble/ai_cup_80-158.csv',index=False)
