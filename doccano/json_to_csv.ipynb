# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('ai_cup_0-79.json', lines=True)
df
# Out:
#                                                  text  \
# 0   醫師：最近人有沒有什麼不舒服？民眾：沒有。醫師：沒有喔。我們本來說要月，年底才打對不對？民眾...
# 1   醫師：要去上課嗎？民眾：沒有。這學期已經開始不上課了。醫師：啊今天的，呃，應該是昨天的抽血。...
# 2   醫師：後來那個吃藥沒有問題對不對？民眾：沒有。醫師：诶？你是打針的？民眾：對。醫師：阿身上有...
# 3   民眾：我自己昨天開始，一天吃一次一粒。醫師：一次一粒，減半量還好？民眾：阿可是……減到今天早...
# 4   醫師：喔，啊嘉明最近還好嗎？民眾：ＯＫ。醫師：啊今年的流感打了嗎？民眾：還沒。醫師：那我們今...
# ..                                                ...
# 74  醫師：子軍這個禮拜感覺怎麼樣？民眾：嗯，痰也是有。醫師：也是有。民眾：可是變白色。醫師：變白...
# 75  醫師：阿吃藥……吃藥會不舒服嗎？民眾：不會。醫師：都還好。民眾：嘿嘿，還好。醫師：阿走路大板...
# 76  民眾：我，我，林醫師，我真的不，我跟你講齁，我住院的時候，這裡我才想起，這裡本來有一點紅啦。...
# 77  醫師：阿人還好嗎？民眾：人還好。醫師：人還好，這次抽……抽血不錯欸。民眾：你看抽血怎麼樣？醫...
# 78  民眾：結果會痛。醫師：你說那個胸口，這樣多久了？民眾：嗯，三個禮拜。醫師：三個禮拜，阿人有發...
#
#                                                labels  \
# 0   [[36, 38, time], [113, 115, time], [198, 200, ...
# 1   [[15, 18, time], [31, 33, time], [40, 42, time...
# 2   [[170, 174, med_exam], [245, 249, med_exam], [...
# 3   [[6, 8, time], [43, 47, time], [221, 223, time...
# ...

# %%
df.drop('metadata', axis=1, inplace=True)
df
# Out:
#                                                  text  \
# 0   醫師：最近人有沒有什麼不舒服？民眾：沒有。醫師：沒有喔。我們本來說要月，年底才打對不對？民眾...
# 1   醫師：要去上課嗎？民眾：沒有。這學期已經開始不上課了。醫師：啊今天的，呃，應該是昨天的抽血。...
# 2   醫師：後來那個吃藥沒有問題對不對？民眾：沒有。醫師：诶？你是打針的？民眾：對。醫師：阿身上有...
# 3   民眾：我自己昨天開始，一天吃一次一粒。醫師：一次一粒，減半量還好？民眾：阿可是……減到今天早...
# 4   醫師：喔，啊嘉明最近還好嗎？民眾：ＯＫ。醫師：啊今年的流感打了嗎？民眾：還沒。醫師：那我們今...
# ..                                                ...
# 74  醫師：子軍這個禮拜感覺怎麼樣？民眾：嗯，痰也是有。醫師：也是有。民眾：可是變白色。醫師：變白...
# 75  醫師：阿吃藥……吃藥會不舒服嗎？民眾：不會。醫師：都還好。民眾：嘿嘿，還好。醫師：阿走路大板...
# 76  民眾：我，我，林醫師，我真的不，我跟你講齁，我住院的時候，這裡我才想起，這裡本來有一點紅啦。...
# 77  醫師：阿人還好嗎？民眾：人還好。醫師：人還好，這次抽……抽血不錯欸。民眾：你看抽血怎麼樣？醫...
# 78  民眾：結果會痛。醫師：你說那個胸口，這樣多久了？民眾：嗯，三個禮拜。醫師：三個禮拜，阿人有發...
#
#                                                labels
# 0   [[36, 38, time], [113, 115, time], [198, 200, ...
# 1   [[15, 18, time], [31, 33, time], [40, 42, time...
# 2   [[170, 174, med_exam], [245, 249, med_exam], [...
# 3   [[6, 8, time], [43, 47, time], [221, 223, time...
# ...

# %%
pos_start_dict = {}
pos_end_dict = {}
entity_dict = {}
type_dict = {}
final_df = pd.DataFrame()
for idx, row in df.iterrows():
    for label in row['labels']:
        print(type(label[0]))
        temp_df = pd.DataFrame({'article_id':idx, 'start_position':label[0], 'end_position':label[1], 'entity_text':row['text'][label[0]:label[1]], 'entity_type':label[2]}
                               ,index=[0])
        final_df = pd.concat([final_df,temp_df])
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
final_df.reset_index(drop=True,inplace=True)

# %%
final_df
# Out:
#       article_id  start_position  end_position entity_text entity_type
# 0              0              36            38          年底        time
# 1              0             113           115          今天        time
# 2              0             198           200          新樓    location
# 3              0             227           229          麻豆    location
# 4              0             237           239          麻豆    location
# ...          ...             ...           ...         ...         ...
# 1731          78             324           328        五月十一        time
# 1732          78             342           344          武漢    location
# 1733          78             399           402         一晚上        time
# 1734          78             552           556        三個禮拜        time
# 1735          78             582           584          今天        time
#
# [1736 rows x 5 columns]

# %%
final_df.to_csv('ai_cup_0-78.csv',index=False)
