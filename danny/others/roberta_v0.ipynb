# %%
import re

# %%
sequence_length = 32

# %%
def txt_to_list(path, sequence_length):
    with open(path, 'r') as f:
        txt = str(f.read())
    txt_list = txt.split('\n')
    text_label_list = list()
    tmp = list()
    for line in txt_list:
        if line == '--------------------':
            text_label_list.append(tmp)
            tmp = list()
            continue
        if line == '':
            continue
        tmp.append(line)
    x = list()
    y = list()
    for text_label in text_label_list:
        text = text_label[0]
        text_list = [i for i in text]
        label = text_label[2:]
        label_list = ['O' for i in range(len(text))]
        for i in label:
            entity = i.split('\t')
            if int(entity[1]) > int(entity[2]):
                continue
            b = int(entity[1])
            label_list[b] = 'B-{}'.format(entity[-1])
            for j in range(int(entity[1])+1, int(entity[2])):
                label_list[j] = 'I-{}'.format(entity[-1])
                
        while len(text_list) > sequence_length:            
            x.append(text_list[:sequence_length])
            y.append(label_list[:sequence_length])
            text_list = text_list[sequence_length:]
            label_list = label_list[sequence_length:]
        x.append(text_list)
        y.append(label_list)
        
    return [x, y]

# %%
x1, y1 = txt_to_list('../datasets/stage1/SampleData_deid.txt', sequence_length)

# %%
x2, y2 = txt_to_list('../datasets/stage2/train_1_update.txt', sequence_length)

# %%
x4, y4 = txt_to_list('../datasets/stage4/train_2.txt', sequence_length)

# %%
x = x1 + x2 + x4
y = y1 + y2 + y4
print(len(x))
print(len(y))
# Out:
# 22532
# 22532

# %%
# print(x[0])

# %%
# print(y[0])

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.2, random_state=42)
train_x, valid_x, train_y, valid_y = train_test_split(train_x, train_y, test_size=0.2, random_state=42)
print(len(train_x), len(train_y))
print(len(valid_x), len(valid_y))
print(len(test_x), len(test_y))
# Out:
# 14420 14420
# 3605 3605
# 4507 4507

# %%
import kashgari
from kashgari.tasks.labeling.models import BiLSTM_CRF_Model
from kashgari.embeddings import BERTEmbedding
kashgari.config.use_cudnn_cell = True

bert_embed = BERTEmbedding('roberta_zh_l12',
                           task=kashgari.LABELING,
                           sequence_length=sequence_length,
                          )

model = BiLSTM_CRF_Model(bert_embed)
model = BiLSTM_CRF_Model()
model.fit(train_x,
          train_y,
          valid_x,
          valid_y,
          epochs=20,
         )
# Out:
# WARNING:root:
# ╭─────────────────────────────────────────────────────────────────────────╮
# │ ◎ ○ ○ ░░░░░░░░░░░░░░░░░░░░░  Important Message  ░░░░░░░░░░░░░░░░░░░░░░░░│
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │              We renamed again for consistency and clarity.              │
# │                   From now on, it is all `kashgari`.                    │
# │  Changelog: https://github.com/BrikerMan/Kashgari/releases/tag/v1.0.0   │
# │                                                                         │
# │         | Backend          | pypi version   | desc           |          │
# │         | ---------------- | -------------- | -------------- |          │
# │         | TensorFlow 2.x   | kashgari 2.x.x | coming soon    |          │
# │         | TensorFlow 1.14+ | kashgari 1.x.x |                |          │
# │         | Keras            | kashgari 0.x.x | legacy version |          │
# │                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────╯
#
# WARNING:root:Unable to use CuDNN cell, no GPU available.
# /home/Danny/anaconda3/lib/python3.6/site-packages/bert4keras/__init__.py:22: UserWarning: bert4keras.bert has been renamed as bert4keras.models.
#   warnings.warn('bert4keras.bert has been renamed as bert4keras.models.')
# /home/Danny/anaconda3/lib/python3.6/site-packages/bert4keras/__init__.py:23: UserWarning: please use bert4keras.models.
#   warnings.warn('please use bert4keras.models.')
# /home/Danny/anaconda3/lib/python3.6/site-packages/bert4keras/__init__.py:44: UserWarning: bert4keras.tokenizer has been renamed as bert4keras.tokenizers.
#   warnings.warn('bert4keras.tokenizer has been renamed as bert4keras.tokenizers.')
# /home/Danny/anaconda3/lib/python3.6/site-packages/bert4keras/__init__.py:45: UserWarning: please use bert4keras.tokenizers.
#   warnings.warn('please use bert4keras.tokenizers.')
# WARNING: Entity <bound method TokenEmbedding.call of <keras_bert.layers.embedding.TokenEmbedding object at 0x7f1ad722b550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method TokenEmbedding.call of <keras_bert.layers.embedding.TokenEmbedding object at 0x7f1ad722b550>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method PositionEmbedding.call of <keras_pos_embd.pos_embd.PositionEmbedding object at 0x7f1ad7065ba8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method PositionEmbedding.call of <keras_pos_embd.pos_embd.PositionEmbedding object at 0x7f1ad7065ba8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad7113080>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad7113080>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad7113cf8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad7113cf8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad6eab748>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad6eab748>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad7008a20>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad7008a20>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad6f82e10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad6f82e10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad6c3d358>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad6c3d358>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad6bb7f60>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad6bb7f60>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad6a0d6a0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad6a0d6a0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad6b555c0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad6b555c0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad69f2550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad69f2550>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad68b1a20>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad68b1a20>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad6723518>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad6723518>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad6511438>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad6511438>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad64ed080>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad64ed080>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad656bb70>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad656bb70>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad62d83c8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad62d83c8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad6212cf8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad6212cf8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad600be80>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad600be80>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad6187b38>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad6187b38>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad6068208>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad6068208>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad5dd59b0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad5dd59b0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad5d11908>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad5d11908>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad3afb438>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad3afb438>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad3b5a240>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad3b5a240>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad5bdcba8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad5bdcba8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad38c4ef0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad38c4ef0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad37ea908>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad37ea908>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad35f0eb8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad35f0eb8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad37f8cc0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad37f8cc0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad364e2e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad364e2e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad33b8860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad33b8860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad12eee48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad12eee48>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad11576d8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad11576d8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad1246da0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad1246da0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad1141518>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad1141518>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad5ec7908>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad5ec7908>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad0df0f28>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad0df0f28>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad0c5ceb8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad0c5ceb8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad0d49080>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad0d49080>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad0d45d30>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad0d45d30>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad09aadd8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad09aadd8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad0957518>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad0957518>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad0755400>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad0755400>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad08402b0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad08402b0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad0732d68>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad0732d68>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad051e860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad051e860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad04c4390>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1ad04c4390>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad024b400>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1ad024b400>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad032be48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1ad032be48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad02a88d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1ad02a88d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1acffc8860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1acffc8860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1acff46128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1acff46128>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1acfd43400>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1acfd43400>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1acfee27b8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1acfee27b8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1acfda1c88>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1acfda1c88>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1acfb0b860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1acfb0b860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1acfa3ce80>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiHeadAttention.call of <keras_multi_head.multi_head_attention.MultiHeadAttention object at 0x7f1acfa3ce80>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1acf837400>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ScaledDotProductAttention.call of <keras_self_attention.scaled_dot_attention.ScaledDotProductAttention object at 0x7f1acf837400>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1acf897320>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1acf897320>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1acf996e48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FeedForward.call of <keras_position_wise_feed_forward.feed_forward.FeedForward object at 0x7f1acf996e48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1acf606860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LayerNormalization.call of <keras_layer_normalization.layer_normalization.LayerNormalization object at 0x7f1acf606860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:root:seq_len: 32
# WARNING:root:Sequence length will auto set at 95% of sequence length
# WARNING: Entity <bound method NonMaskingLayer.call of <kashgari.layers.non_masking_layer.NonMaskingLayer object at 0x7f19b072feb8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method NonMaskingLayer.call of <kashgari.layers.non_masking_layer.NonMaskingLayer object at 0x7f19b072feb8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method CRF.call of <kashgari.layers.crf.CRF object at 0x7f19b0668f60>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method CRF.call of <kashgari.layers.crf.CRF object at 0x7f19b0668f60>>: AttributeError: module 'gast' has no attribute 'Num'
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 32)]              0
# _________________________________________________________________
# layer_embedding (Embedding)  (None, 32, 100)           173600
# _________________________________________________________________
# layer_blstm (Bidirectional)  (None, 32, 256)           234496
# _________________________________________________________________
# layer_dense (Dense)          (None, 32, 64)            16448
# _________________________________________________________________
# layer_crf_dense (Dense)      (None, 32, 27)            1755
# _________________________________________________________________
# layer_crf (CRF)              (None, 32, 27)            729
# =================================================================
# Total params: 427,028
# Trainable params: 427,028
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 226/226 [==============================] - 20s 87ms/step - loss: 10.4189 - accuracy: 0.9491 - val_loss: 74.0958 - val_accuracy: 0.9724
# Epoch 2/20
# 226/226 [==============================] - 16s 72ms/step - loss: 2.8928 - accuracy: 0.9778 - val_loss: 73.1505 - val_accuracy: 0.9771
# Epoch 3/20
# 226/226 [==============================] - 16s 72ms/step - loss: 2.0163 - accuracy: 0.9805 - val_loss: 72.4948 - val_accuracy: 0.9799
# Epoch 4/20
# 226/226 [==============================] - 16s 72ms/step - loss: 1.6219 - accuracy: 0.9814 - val_loss: 71.8194 - val_accuracy: 0.9818
# Epoch 5/20
# 226/226 [==============================] - 16s 72ms/step - loss: 1.3525 - accuracy: 0.9830 - val_loss: 71.2059 - val_accuracy: 0.9814
# Epoch 6/20
# 226/226 [==============================] - 16s 72ms/step - loss: 1.1533 - accuracy: 0.9846 - val_loss: 70.5355 - val_accuracy: 0.9845
# Epoch 7/20
# 226/226 [==============================] - 16s 72ms/step - loss: 0.9779 - accuracy: 0.9862 - val_loss: 69.9450 - val_accuracy: 0.9851
# Epoch 8/20
# 226/226 [==============================] - 16s 71ms/step - loss: 0.8428 - accuracy: 0.9875 - val_loss: 69.4224 - val_accuracy: 0.9832
# Epoch 9/20
# 226/226 [==============================] - 16s 72ms/step - loss: 0.7543 - accuracy: 0.9886 - val_loss: 68.9265 - val_accuracy: 0.9814
# Epoch 10/20
# 226/226 [==============================] - 16s 72ms/step - loss: 0.6819 - accuracy: 0.9891 - val_loss: 68.3419 - val_accuracy: 0.9740
# Epoch 11/20
# 226/226 [==============================] - 16s 72ms/step - loss: 0.6193 - accuracy: 0.9900 - val_loss: 67.9134 - val_accuracy: 0.1584
# Epoch 12/20
# 226/226 [==============================] - 16s 72ms/step - loss: 0.5538 - accuracy: 0.9907 - val_loss: 67.3586 - val_accuracy: 0.1044
# Epoch 13/20
# 226/226 [==============================] - 16s 72ms/step - loss: 0.5028 - accuracy: 0.9912 - val_loss: 66.9587 - val_accuracy: 0.0839
# Epoch 14/20
# 226/226 [==============================] - 16s 72ms/step - loss: 0.4501 - accuracy: 0.9924 - val_loss: 66.4562 - val_accuracy: 0.0693
# Epoch 15/20
# 226/226 [==============================] - 16s 72ms/step - loss: 0.4067 - accuracy: 0.9930 - val_loss: 66.0072 - val_accuracy: 0.0630
# Epoch 16/20
# 226/226 [==============================] - 16s 72ms/step - loss: 0.3741 - accuracy: 0.9935 - val_loss: 65.6002 - val_accuracy: 0.0612
# Epoch 17/20
# 226/226 [==============================] - 16s 71ms/step - loss: 0.3321 - accuracy: 0.9943 - val_loss: 65.2603 - val_accuracy: 0.0616
# Epoch 18/20
# 226/226 [==============================] - 16s 71ms/step - loss: 0.2996 - accuracy: 0.9949 - val_loss: 64.8007 - val_accuracy: 0.0279
# Epoch 19/20
# 226/226 [==============================] - 16s 71ms/step - loss: 0.2716 - accuracy: 0.9954 - val_loss: 64.3967 - val_accuracy: 0.0266
# Epoch 20/20
# 226/226 [==============================] - 16s 71ms/step - loss: 0.2425 - accuracy: 0.9958 - val_loss: 64.0553 - val_accuracy: 0.0530

# %%
model.evaluate(test_x, test_y)
model.save('model/roberta_BiLSTM_CRF_len_32_epo_20')
# Out:
#                 precision    recall  f1-score   support
#
#           time     0.7149    0.7689    0.7409       913
#             ID     0.0000    0.0000    0.0000        10
#       location     0.7248    0.7900    0.7560       100
#         family     0.6250    0.3846    0.4762        13
#       med_exam     0.8348    0.6531    0.7328       147
#           name     0.6852    0.7872    0.7327        94
#          money     0.6615    0.8431    0.7414        51
#        contact     0.6471    0.5500    0.5946        20
#     profession     0.4444    0.3636    0.4000        11
# clinical_event     0.0000    0.0000    0.0000         4
#   organization     0.0000    0.0000    0.0000         4
#         others     0.0000    0.0000    0.0000         3
#
#      micro avg     0.7171    0.7401    0.7284      1370
#      macro avg     0.7095    0.7401    0.7218      1370

# %%
model = kashgari.utils.load_model('model/roberta_BiLSTM_CRF_len_32_epo_20')
# Out:
# WARNING:root:Sequence length will auto set at 95% of sequence length
# /home/Danny/anaconda3/lib/python3.6/site-packages/bert4keras/__init__.py:22: UserWarning: bert4keras.bert has been renamed as bert4keras.models.
#   warnings.warn('bert4keras.bert has been renamed as bert4keras.models.')
# /home/Danny/anaconda3/lib/python3.6/site-packages/bert4keras/__init__.py:23: UserWarning: please use bert4keras.models.
#   warnings.warn('please use bert4keras.models.')
# /home/Danny/anaconda3/lib/python3.6/site-packages/bert4keras/__init__.py:44: UserWarning: bert4keras.tokenizer has been renamed as bert4keras.tokenizers.
#   warnings.warn('bert4keras.tokenizer has been renamed as bert4keras.tokenizers.')
# /home/Danny/anaconda3/lib/python3.6/site-packages/bert4keras/__init__.py:45: UserWarning: please use bert4keras.tokenizers.
#   warnings.warn('please use bert4keras.tokenizers.')
# WARNING: Entity <bound method CRF.call of <kashgari.layers.crf.CRF object at 0x7f18c10662b0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method CRF.call of <kashgari.layers.crf.CRF object at 0x7f18c10662b0>>: AttributeError: module 'gast' has no attribute 'Num'

# %%
import pandas as pd
df = pd.read_csv('../datasets/stage4/development_2.csv')

# %%
def predict_NER(model, text, sequence_length):
    x_list = list()
    while len(text) > sequence_length:
        x_list.append([i for i in text[:sequence_length]])
        text = text[sequence_length:]        
    x_list.append([i for i in text[:sequence_length]])
    y_list = model.predict(x_list)
    merge_list = list()
    for i in y_list:
        for j in i:
            merge_list.append(j)
    return merge_list

# %%
def output_NER(article_id, text, y):
    output = str()
    flag = False
    for i, j in enumerate(y):
        if j != 'O':
            if j[0] == 'B':
                start_position = i
                entity_type = j.split('-')[-1]
                flag = True
        elif j == 'O' and flag == True:
            end_position = i
            flag = False
            entity_text = text[start_position: end_position]
            output += '{}\t{}\t{}\t{}\t{}\n'.format(article_id, start_position, end_position, entity_text, entity_type)  
    return output

# %%
output="article_id\tstart_position\tend_position\tentity_text\tentity_type\n"
for article_id, text in zip(df['article_id'], df['text']):
    y = predict_NER(model, text, sequence_length)
    output += output_NER(article_id, text, y)

# %%
print(output)
# Out:
# article_id	start_position	end_position	entity_text	entity_type
# 0	273	276	李醫生	name
# 0	326	328	25	med_exam
# 0	400	403	11點	time
# 0	467	469	廁所	name
# 0	615	619	11點多	time
# 0	645	647	兩天	time
# 0	1168	1172	7月21	time
# 0	2200	2203	13號	time
# 0	2214	2217	15天	time
# 0	2226	2228	3天	time
# 0	2245	2247	三天	time
# 0	2319	2322	禮拜一	time
# 0	2332	2335	禮拜一	time
# 0	2344	2347	上廁所	name
# 0	2353	2356	上廁所	name
# 0	2360	2363	上廁所	name
# 0	2372	2375	前幾天	time
# 0	2624	2628	下下禮拜	time
# 0	2738	2740	林區	name
# 0	2780	2782	北區	location
# 0	2807	2810	下禮拜	time
# 0	3306	3309	3天份	time
# 0	3340	3343	下禮拜	time
# 1	66	69	108	med_exam
# 1	457	460	五月中	time
# 2	27	32	8月17號	time
# 2	40	45	上上個禮拜	time
# 2	53	56	110	med_exam
# 2	85	88	110	med_exam
# 2	111	114	6.0	med_exam
# 2	253	256	126	time
# 2	279	281	2年	time
# 2	496	498	泰國	location
# 2	524	527	釣蝦子	name
# 2	718	720	斜斜	name
# 2	770	772	斜斜	name
# 2	779	781	斜斜	name
# 2	1096	1098	半年	time
# 2	1118	1120	半年	time
# 2	1147	1150	三個月	time
# 2	1226	1231	一兩個禮拜	time
# 3	183	186	7點多	med_exam
# 3	187	190	8點多	med_exam
# 3	233	236	9點多	time
# 3	240	243	10點	time
# 3	250	255	6月15號	time
# 3	256	261	16號左右	time
# 3	265	268	16號	time
# 3	272	274	14	time
# 3	275	277	15	time
# 3	278	281	16號	time
# 3	302	306	1個禮拜	time
# 3	576	580	6月4號	time
# 3	582	584	前年	time
# 3	592	594	前年	time
# 3	913	917	50分鐘	time
# 3	1431	1434	禮拜1	time
# 3	1443	1446	禮拜2	time
# 3	1447	1450	4、6	time
# 3	1456	1459	禮拜2	time
# 3	1472	1475	禮拜2	time
# 3	1489	1492	禮拜1	time
# 3	1873	1877	4、5月	time
# 3	1890	1894	108年	time
# 3	1899	1903	106年	time
# 3	1910	1914	106年	time
# 3	1921	1925	4、5月	time
# 3	1929	1931	四月	time
# 3	1932	1934	五月	time
# 3	2023	2025	5月	time
# 3	2033	2036	8月份	time
# 3	2041	2043	8月	time
# 3	2046	2048	8月	time
# 3	2102	2104	5年	time
# 3	2105	2107	5年	time
# 3	2178	2183	八月23日	time
# 3	2195	2200	八月23日	time
# 3	2204	2207	八月份	time
# 3	2219	2222	6、7	time
# 3	2223	2225	8月	time
# 3	2230	2233	八月份	time
# 3	2250	2254	106年	time
# 3	2390	2392	鋼釘	name
# 3	2393	2395	鋼釘	name
# 3	2752	2754	今天	time
# 3	3081	3087	1、2個小時	time
# 3	3108	3114	1、2個小時	time
# 4	7	12	6月14號	time
# 4	42	44	13	money
# 4	45	47	14	med_exam
# 4	146	148	昨天	time
# 4	187	190	林醫師	name
# 4	338	343	前一個禮拜	time
# 4	354	358	上個禮拜	time
# 4	372	374	黃黃	name
# 4	388	392	一個禮拜	time
# 4	615	617	今天	time
# 4	623	625	昨天	time
# 4	666	668	昨天	time
# 4	684	690	60多70多	money
# 4	726	728	晚上	time
# 4	731	734	林醫師	name
# 4	806	809	林醫師	name
# 4	815	818	林醫師	name
# 4	838	840	昨天	time
# 4	844	847	林醫師	name
# 4	872	877	6月24號	time
# 4	880	883	林醫師	name
# 4	1051	1054	呂醫師	name
# 4	1536	1540	上許醫師	name
# 4	1606	1609	林醫師	name
# 4	1620	1623	林醫師	name
# 4	1665	1668	林醫師	name
# 4	1692	1695	張醫師	name
# 4	1704	1706	昨天	time
# 4	1720	1723	巫醫師	name
# 4	1811	1814	林醫師	name
# 4	1912	1915	巫醫師	name
# 4	1960	1963	三個月	time
# 4	1967	1970	三個月	time
# 4	1974	1977	三個月	time
# 4	1979	1982	三個月	time
# 4	1988	1991	三個月	time
# 4	2000	2004	一天一天	time
# 4	2082	2084	漸漸	name
# 5	83	87	今天早上	time
# 5	88	90	八點	time
# 5	861	864	1．6	time
# 5	968	970	2點	time
# 5	1047	1049	昨天	time
# 5	1052	1055	10點	time
# 5	1183	1184	承	name
# 5	1876	1880	一個禮拜	time
# 5	1888	1890	三先	time
# 5	1893	1896	禮拜三	time
# 5	1919	1920	上	time
# 5	1922	1925	禮拜三	time
# 5	2423	2425	老媽	family
# 5	2433	2436	禮拜三	time
# 5	2437	2441	6月6號	time
# 5	2725	2727	7個	time
# 5	2728	2730	7個	time
# 6	86	88	前年	time
# 6	160	162	5月	time
# 6	376	380	7月4號	time
# 6	802	805	三四天	time
# 6	822	825	三四天	time
# 6	829	832	三四天	time
# 6	994	997	418	med_exam
# 6	1003	1006	418	med_exam
# 6	1041	1044	418	med_exam
# 6	1091	1093	小姐	name
# 6	1170	1173	343	med_exam
# 6	1177	1180	343	med_exam
# 6	1217	1219	今天	time
# 6	1227	1229	今天	time
# 6	1250	1253	吳醫師	name
# 6	1454	1456	早上	time
# 6	1550	1554	一個禮拜	time
# 6	1625	1627	櫻木	name
# 7	240	243	132	med_exam
# 7	247	250	132	med_exam
# 7	272	274	91	med_exam
# 7	278	280	91	med_exam
# 7	319	320	平	time
# 7	323	325	72	med_exam
# 7	432	435	張醫師	name
# 7	717	720	三百多	med_exam
# 7	889	892	三個月	time
# 7	910	913	三個月	time
# 7	1038	1041	三個月	time
# 7	1045	1048	三個月	time
# 7	1055	1056	一	time
# 8	215	218	黃醫師	name
# 8	262	265	黃醫師	name
# 8	484	486	晚上	time
# 8	533	536	黃醫師	name
# 8	601	604	一個月	time
# 8	605	607	兩個	time
# 8	685	689	兩個禮拜	time
# 8	764	767	黃醫師	name
# 8	932	935	王阿明	name
# 9	35	37	五月	time
# 9	84	87	一個月	time
# 9	273	282	ｓｕｂｔａｔｉｏｎ	name
# 9	314	316	9月	time
# 9	417	419	73	med_exam
# 9	439	442	170	med_exam
# 9	446	449	170	med_exam
# 10	71	73	74	med_exam
# 10	78	80	74	med_exam
# 10	160	164	下下禮拜	time
# 10	175	178	下禮拜	time
# 10	181	185	下禮拜三	time
# 10	221	224	一個月	time
# 10	241	245	兩個禮拜	time
# 10	262	266	四個禮拜	time
# 10	472	476	四個禮拜	time
# 10	491	494	禮拜三	time
# 10	537	541	十月六號	time
# 11	3	9	120、71	time
# 11	17	21	18.5	time
# 11	26	29	上禮拜	time
# 11	132	135	林醫師	name
# 11	143	146	林醫師	name
# 11	154	158	紐約醫院	location
# 11	174	178	紐約醫院	location
# 11	199	202	10年	time
# 11	210	213	林醫師	name
# 11	280	282	阿美	name
# 11	313	316	林醫師	name
# 11	363	364	榮	location
# 11	368	371	巫醫師	name
# 11	376	379	王醫師	name
# 11	418	419	榮	location
# 11	455	458	林醫師	name
# 11	513	516	林醫師	name
# 11	592	594	兩年	time
# 11	676	680	紐約醫院	location
# 11	729	732	三個月	time
# 11	763	766	四個月	time
# 11	930	933	林醫師	name
# 11	1097	1099	6月	time
# 11	1153	1156	兩個月	time
# 11	1233	1236	兩個月	time
# 11	1238	1241	兩個月	time
# 11	1273	1276	兩個月	time
# 11	1353	1355	紐約	location
# 11	1358	1362	紐約醫院	location
# 11	1416	1419	兩個月	time
# 11	1436	1438	兩天	time
# 11	1470	1472	紐約	location
# 11	1647	1649	兩年	time
# 11	1869	1872	林醫師	name
# 11	1888	1890	去年	time
# 11	2014	2016	今年	time
# 11	2029	2032	林醫師	name
# 11	2137	2140	4個月	time
# 11	2144	2147	4個月	time
# 11	2148	2154	10月17號	time
# 11	2347	2350	巫醫師	name
# 12	342	345	129	med_exam
# 12	349	352	129	med_exam
# 12	364	366	81	time
# 12	407	412	7月26號	time
# 12	434	436	92	med_exam
# 12	855	857	85	med_exam
# 12	885	887	85	med_exam
# 13	48	52	9月2號	time
# 13	60	63	9．7	med_exam
# 13	87	89	56	med_exam
# 13	126	128	56	time
# 13	158	161	9．6	med_exam
# 13	166	169	9．8	med_exam
# 13	188	191	9．6	med_exam
# 13	446	448	早上	time
# 13	463	465	3月	time
# 13	481	484	7個月	time
# 13	488	491	10月	time
# 13	492	496	10月底	time
# 13	723	725	中央	family
# 14	27	30	753	med_exam
# 14	45	47	37	med_exam
# 14	123	125	兩天	time
# 14	137	139	三天	time
# 14	242	246	38.7	med_exam
# 14	250	253	387	med_exam
# 14	371	374	68點	med_exam
# 14	379	380	7	med_exam
# 14	384	388	68.7	med_exam
# 14	459	462	2個月	time
# 14	476	479	2個月	time
# 14	621	624	這個月	time
# 14	655	657	8月	time
# 14	662	664	4月	time
# 14	671	673	4月	time
# 14	701	703	8月	time
# 14	1094	1096	今年	time
# 14	1132	1140	前、前、前兩個月	time
# 14	1173	1177	5月21	time
# 14	1179	1184	5月21號	time
# 14	1385	1390	9月20號	time
# 14	1396	1398	9月	time
# 15	92	95	2.4	med_exam
# 15	99	102	2.4	med_exam
# 15	177	179	58	med_exam
# 15	182	185	2.4	med_exam
# 15	632	634	前鎮	location
# 15	1228	1231	五十幾	med_exam
# 15	1288	1291	一個月	time
# 15	1452	1456	0.55	med_exam
# 15	1462	1465	90分	med_exam
# 16	203	207	三個禮拜	time
# 16	218	222	六個禮拜	time
# 16	235	239	六個禮拜	time
# 16	257	261	六個禮拜	time
# 16	324	328	5.02	med_exam
# 16	337	341	7.64	med_exam
# 16	353	357	0.62	med_exam
# 16	367	371	7.83	med_exam
# 16	383	386	8.5	med_exam
# 16	391	393	8.	med_exam
# 16	397	401	7.83	med_exam
# 16	402	406	7.02	med_exam
# 16	424	427	三個月	time
# 16	715	719	林大醫師	name
# 17	1578	1580	明天	time
# 17	1584	1587	明後天	time
# 17	1593	1595	明天	time
# 17	1596	1599	禮拜一	time
# 17	1604	1606	明天	time
# 17	1611	1616	今天禮拜天	time
# 17	1621	1626	今天禮拜天	time
# 17	1630	1632	禮拜	time
# 17	1637	1640	禮拜一	time
# 17	1656	1659	禮拜二	time
# 17	1663	1666	禮拜二	time
# 17	1678	1682	押禮拜二	time
# 17	1692	1694	小花	name
# 17	2026	2028	跨月	time
# 17	2034	2036	五月	time
# 17	2038	2041	五月份	time
# 17	2062	2065	六月份	time
# 17	2167	2169	台中	location
# 17	2174	2176	四天	time
# 17	2179	2181	七天	time
# 17	2185	2187	台中	location
# 17	2344	2346	五月	time
# 17	2467	2469	兩天	time
# 17	2506	2509	前三天	time
# 17	2862	2864	」「	name
# 18	21	24	五月中	time
# 18	210	213	120	med_exam
# 18	237	240	921	med_exam
# 18	265	270	500以上	time
# 18	429	432	三個月	time
# 19	932	935	0.1	med_exam
# 19	1812	1814	五次	time
# 19	1906	1909	150	med_exam
# 19	2498	2501	下禮拜	time
# 19	3082	3084	陽明	location
# 19	3837	3839	陽明	name
# 19	3869	3871	陽明	name
# 19	4006	4008	學區	location
# 19	4018	4019	榮	location
# 19	4022	4024	學區	location
# 19	4098	4100	八天	time
# 19	4101	4104	十四天	time
# 19	4140	4145	五、六十歲	time
# 19	4209	4211	晚上	time
# 19	4228	4231	大醫院	location
# 19	4462	4464	一系	location
# 19	5007	5009	昨天	time
# 19	5487	5490	下禮拜	time
# 19	5625	5628	下禮拜	time
# 19	5949	5952	下禮拜	time
# 19	6021	6024	下禮拜	time
# 20	10	13	這個月	time
# 20	332	334	兩三	time
# 20	766	769	東花蓮	location
# 20	1010	1014	一兩年前	time
# 20	1307	1313	三個月三個月	time
# 20	1314	1317	三個月	time
# 20	2147	2149	三天	time
# 20	3013	3016	三個月	time
# 20	4646	4650	8月2號	time
# 20	4659	4664	8月20號	time
# 21	293	295	一號	time
# 21	1279	1280	2	time
# 21	1781	1783	許多	name
# 21	1921	1923	新聞	name
# 21	2553	2554	彰	location
# 21	2714	2716	泰國	location
# 21	2723	2725	泰國	location
# 21	2944	2949	兩週到六週	time
# 21	3323	3325	泰國	location
# 21	3326	3328	印度	location
# 22	6	9	王醫師	name
# 22	112	115	王醫師	name
# 22	523	525	陽明	name
# 22	743	745	陽明	name
# 22	981	984	四個月	time
# 22	989	992	四個月	time
# 22	1173	1175	承認	name
# 22	2109	2112	六個月	time
# 22	2736	2739	王醫師	name
# 22	3361	3364	三六九	time
# 22	3390	3392	兩個	time
# 22	3484	3488	一萬多塊	money
# 22	3604	3607	王醫師	name
# 22	3612	3615	禮拜一	time
# 22	3616	3618	早上	time
# 22	3619	3622	禮拜三	time
# 22	3623	3625	下午	time
# 22	3637	3640	禮拜一	time
# 22	3641	3644	禮拜三	time
# 22	3691	3694	每個月	time
# 22	3702	3705	王醫師	name
# 23	6	9	王醫師	name
# 23	57	60	王醫師	name
# 23	207	210	211	time
# 23	248	252	成211	time
# 23	576	579	王醫師	name
# 23	636	639	王醫師	name
# 23	1002	1007	一個禮拜一	time
# 23	1020	1024	禮拜一兩	time
# 23	1090	1094	一個禮拜	time
# 23	1126	1130	2111	time
# 23	1243	1246	明白明	name
# 23	1756	1759	王醫師	name
# 24	55	58	這個月	time
# 24	174	176	兩天	time
# 24	259	263	一個禮拜	time
# 24	382	384	七天	time
# 24	421	423	四天	time
# 24	716	718	台中	location
# 24	737	739	檳榔	name
# 25	7	10	這個月	time
# 25	147	158	12345678910	ID
# 25	159	160	二	time
# 25	193	196	28天	time
# 25	268	271	一個月	time
# 25	287	288	兩	time
# 25	1130	1133	四五天	time
# 25	1222	1225	三四天	time
# 26	15	17	5月	time
# 26	200	205	1組多2組	money
# 26	234	236	周末	time
# 26	302	305	一個月	time
# 26	307	309	2組	time
# 26	714	716	69	med_exam
# 26	962	964	今天	time
# 26	974	976	今天	time
# 26	1166	1172	tinder	contact
# 26	2130	2134	5、6瓶	time
# 26	2339	2342	三個月	time
# 26	2542	2545	三個月	time
# 26	2569	2572	林小姐	name
# 27	11	13	台中	location
# 27	262	267	上台中七天	time
# 27	326	330	這一個月	time
# 27	355	358	上個月	time
# 27	373	377	今天十三	time
# 27	398	401	十三天	time
# 27	451	454	十三天	time
# 27	517	520	十三天	time
# 27	589	592	這禮拜	time
# 27	594	597	一個月	time
# 28	30	32	一年	time
# 28	64	66	一年	time
# 28	1158	1160	昨天	time
# 28	1161	1163	前天	time
# 28	2553	2555	四天	time
# 29	33	35	桃園	location
# 29	41	43	桃園	location
# 29	51	53	小蘭	name
# 29	215	217	一年	time
# 29	224	226	一年	time
# 29	230	232	一年	time
# 29	256	259	三個月	time
# 29	747	750	陳醫師	name
# 29	1344	1347	12瓶	time
# 29	1376	1383	16000多塊	money
# 29	1386	1391	17000	money
# 29	1608	1610	今天	time
# 29	1673	1676	每個月	time
# 29	1758	1760	北區	location
# 29	1838	1841	369	med_exam
# 29	1924	1928	前3個月	time
# 29	1929	1931	前3	time
# 29	1939	1941	7月	time
# 29	1942	1944	8月	time
# 29	1945	1947	9月	time
# 29	2026	2030	7月6號	time
# 29	2054	2056	8月	time
# 29	2059	2062	一個月	time
# 29	2153	2155	9月	time
# 30	219	221	8年	time
# 30	250	252	嘉義	location
# 30	256	260	兩到三天	time
# 30	288	292	一個禮拜	time
# 30	444	448	今天禮拜	time
# 30	449	452	禮拜二	time
# 30	488	492	3456	med_exam
# 30	510	512	禮拜	time
# 30	525	528	禮拜日	time
# 30	841	844	211	time
# 30	1158	1160	一年	time
# 30	1538	1540	30	money
# 30	1593	1597	第6個月	time
# 30	1600	1602	今天	time
# 30	1629	1631	半年	time
# 31	203	207	晚上11	time
# 31	278	281	4個月	time
# 31	873	877	這個月內	time
# 31	911	914	這個月	time
# 31	1028	1030	IG	profession
# 31	1804	1806	今天	time
# 31	1812	1814	今天	time
# 31	1862	1865	9月中	time
# 31	1874	1878	12月中	time
# 31	1890	1894	12月中	time
# 31	1924	1928	8月3號	time
# 31	2012	2015	三個月	time
# 32	495	502	一個月2、3次	time
# 32	512	516	一個月2	time
# 32	590	592	今天	time
# 32	594	596	明天	time
# 32	946	948	兩天	time
# 32	949	951	八點	time
# 32	1208	1210	小美	name
# 32	1312	1315	六個月	time
# 32	1433	1436	三個月	time
# 32	1444	1447	五千塊	money
# 32	1458	1460	四千	money
# 32	1461	1463	五千	med_exam
# 32	1542	1544	泰國	location
# 32	1901	1904	每個月	time
# 32	1950	1952	五百	time
# 32	1967	1969	嘉義	location
# 32	2129	2132	一個月	time
# 32	2408	2411	三個月	time
# 32	2596	2598	一年	time
# 32	2652	2654	一年	time
# 32	2668	2671	三個月	time
# 32	2730	2732	一年	time
# 33	44	47	禮拜二	time
# 33	48	50	早上	time
# 33	51	54	禮拜五	time
# 33	55	57	下午	time
# 33	112	114	2組	med_exam
# 33	838	842	5、6瓶	time
# 33	880	885	10月7號	time
# 33	920	923	五下午	time
# 34	88	93	萬華的北醫	name
# 34	98	103	萬華的北醫	location
# 34	436	440	四五年前	time
# 34	513	515	半年	time
# 34	724	727	半年前	time
# 34	732	734	半年	time
# 34	772	775	五個月	time
# 34	779	782	五個月	time
# 34	1536	1538	昨天	time
# 34	1805	1809	一個禮拜	time
# 34	2693	2696	6個月	time
# 34	2795	2797	今天	time
# 34	2804	2810	1800多塊	money
# 34	2859	2863	800多	time
# 34	2874	2877	三個月	time
# 34	2882	2885	700	time
# 34	2946	2951	1000塊	money
# 34	2984	2987	一個月	time
# 34	4220	4223	下禮拜	time
# 34	4248	4251	禮拜二	time
# 34	4252	4254	晚上	time
# 34	4292	4295	禮拜三	time
# 34	4296	4298	下午	time
# 34	4299	4302	禮拜五	time
# 34	4303	4305	早上	time
# 34	4308	4310	兩天	time
# 34	4418	4420	下午	time
# 34	4421	4424	禮拜五	time
# 34	4425	4427	早上	time
# 34	4433	4436	禮拜五	time
# 34	4437	4439	早上	time
# 34	4450	4454	下禮拜五	time
# 34	4459	4462	禮拜五	time
# 34	4482	4486	下禮拜五	time
# 34	4495	4498	禮拜五	time
# 34	4499	4501	早上	time
# 34	4502	4507	7月21號	time
# 34	4572	4574	萬華	location
# 34	4582	4587	萬華的北醫	location
# 34	4593	4598	萬華的北醫	name
# 35	168	171	陳小姐	name
# 35	221	224	陳小姐	name
# 35	831	832	曾	location
# 35	1674	1678	1個禮拜	time
# 35	1952	1956	兩個小時	time
# 35	2105	2107	週末	time
# 35	2118	2120	週末	time
# 35	2132	2135	禮拜一	time
# 35	2137	2139	早上	time
# 35	2142	2144	一兩	time
# 35	2370	2372	今天	time
# 35	3251	3254	九十五	time
# 35	3793	3795	3個	time
# 35	3979	3982	28天	time
# 35	4228	4233	12000	time
# 35	4313	4316	一萬三	money
# 35	4446	4448	泰國	location
# 35	4621	4623	美國	name
# 35	4702	4703	明	name
# 35	4741	4743	泰國	location
# 35	4780	4784	500塊	money
# 35	4785	4789	600塊	money
# 35	4810	4812	泰國	location
# 35	4836	4842	1500台幣	money
# 35	4854	4858	500塊	money
# 35	4859	4863	600塊	money
# 35	5071	5076	下下個禮拜	time
# 36	17	20	六點半	time
# 36	28	31	六點半	time
# 36	43	48	七點四十二	time
# 36	116	119	這個月	time
# 36	586	590	第七個月	time
# 36	601	604	下半年	time
# 36	660	665	四月二十五	time
# 36	678	683	四月二十五	time
# 36	715	720	四月二十五	time
# 37	4	7	這個月	time
# 37	222	224	早上	time
# 37	229	231	早上	time
# 37	766	768	兩個	time
# 37	981	986	400多塊	money
# 37	1069	1072	4千多	money
# 37	1073	1075	5千	money
# 37	1321	1324	一個月	time
# 37	1326	1330	1500	money
# 38	70	72	高雄	location
# 38	84	86	高雄	location
# 38	92	94	高雄	location
# 38	115	117	七天	time
# 38	138	143	八⋯⋯八號	time
# 38	160	164	兩個禮拜	time
# 38	177	179	高雄	name
# 38	423	425	七天	time
# 38	582	584	高雄	location
# 38	632	633	七	time
# 38	636	637	九	time
# 38	641	644	下個月	time
# 38	648	651	下個月	time
# 38	662	664	今天	time
# 39	22	25	一個月	time
# 39	141	144	三個月	time
# 39	770	773	六個月	time
# 39	1715	1720	兩、三個月	time
# 40	60	61	系	location
# 40	399	402	廖醫師	name
# 40	516	519	一年前	time
# 40	539	541	區塊	name
# 40	548	550	區塊	profession
# 40	561	564	半年前	time
# 40	846	848	今天	time
# 40	855	858	兩年期	time
# 40	975	977	今天	time
# 41	101	104	張醫師	name
# 41	109	112	張醫師	name
# 41	361	363	唱歌	name
# 41	623	626	張醫師	name
# 41	766	768	15	time
# 41	982	985	張醫師	name
# 41	1014	1017	張醫師	name
# 41	1061	1063	老媽	profession
# 41	1066	1068	老媽	profession
# 41	1172	1174	孫子	profession
# 41	1216	1218	孫子	location
# 41	1221	1223	孫女	family
# 41	1249	1252	張大明	name
# 41	1280	1282	禮拜	time
# 41	1358	1361	南一中	location
# 41	1471	1472	陳	name
# 41	1856	1858	每天	time
# 41	1905	1908	三個月	time
# 41	1952	1954	AG	location
# 42	675	678	黃醫師	name
# 42	679	684	黃明明醫師	name
# 42	688	693	黃明明醫師	name
# 42	1136	1138	德國	location
# 42	1433	1436	李醫師	name
# 42	2001	2004	送醫院	location
# 42	2021	2024	119	time
# 42	2391	2394	119	med_exam
# 42	2726	2729	119	med_exam
# 43	3	5	仙道	name
# 43	213	216	三個月	time
# 43	220	222	半年	time
# 43	229	231	明天	time
# 43	264	269	7月12號	time
# 43	287	291	兩個禮拜	time
# 43	449	451	56	med_exam
# 43	455	457	56	med_exam
# 43	483	488	7月12號	time
# 43	553	555	禮拜	time
# 43	560	562	早上	time
# 43	565	567	中午	time
# 43	678	682	4個禮拜	time
# 43	702	704	下午	time
# 43	715	717	早上	time
# 43	762	765	禮拜五	time
# 43	766	768	早上	time
# 43	819	823	兩個禮拜	time
# 43	828	831	810	time
# 43	832	837	8月10號	time
# 43	864	866	禮拜	time
# 43	939	941	早上	time
# 43	971	975	3個禮拜	time
# 43	1085	1087	7天	time
# 43	1129	1131	7天	time
# 43	1135	1137	7天	time
# 43	1175	1179	兩個禮拜	time
# 43	1354	1358	3000	money
# 43	1359	1363	8000	money
# 43	1550	1553	3個月	time
# 43	1560	1563	三個月	time
# 43	1566	1569	3個月	time
# 43	1637	1640	6個月	time
# 44	4	8	這個禮拜	time
# 44	17	21	這個禮拜	time
# 44	33	34	嗅	name
# 44	710	714	兩個禮拜	time
# 44	1220	1222	12	time
# 44	1662	1664	日本	location
# 44	1730	1732	兩波	location
# 44	1787	1790	下禮拜	time
# 45	93	97	7月12	time
# 45	105	107	12	time
# 45	453	455	小俊	name
# 45	477	480	兩個月	time
# 45	485	488	兩個月	time
# 45	507	510	28天	time
# 45	516	520	第二個月	time
# 45	564	567	3個月	time
# 45	574	576	8月	time
# 45	585	588	11月	time
# 45	616	620	8月18	time
# 45	627	630	9月初	time
# 45	634	637	8月初	time
# 45	640	643	9月底	time
# 45	646	649	兩個月	time
# 45	665	668	兩個月	time
# 45	678	681	兩個月	time
# 45	704	710	11月30號	time
# 45	920	926	11月30號	time
# 45	1153	1156	兩個月	time
# 45	1162	1167	1555塊	money
# 45	1254	1257	兩個月	time
# 46	88	90	兩天	time
# 46	233	237	7月21	time
# 46	238	242	7月23	time
# 46	246	250	7月21	time
# 46	251	255	7月23	time
# 46	259	262	一二三	time
# 46	267	270	一二三	time
# 46	274	279	上個禮拜三	time
# 46	288	291	禮拜四	time
# 46	341	346	7月23號	time
# 46	405	409	37.5	med_exam
# 46	452	454	早上	time
# 46	456	459	36幾	time
# 46	466	468	晚上	time
# 46	469	471	下午	time
# 46	485	489	37.2	med_exam
# 46	496	500	37.5	med_exam
# 46	521	523	下午	time
# 46	589	591	早上	time
# 46	604	606	早上	time
# 46	613	615	下午	time
# 46	707	711	36.5	med_exam
# 46	734	736	37	time
# 46	749	752	37度	med_exam
# 46	877	879	37	med_exam
# 46	993	995	75	med_exam
# 46	1048	1050	30	money
# 46	1054	1056	13	med_exam
# 46	1313	1316	七八十	med_exam
# 46	1349	1352	189	med_exam
# 46	1356	1359	201	med_exam
# 46	1456	1458	13	med_exam
# 46	1460	1462	4.	med_exam
# 46	1617	1621	兩到三天	time
# 46	1636	1638	兩天	time
# 46	1688	1690	21	time
# 46	1691	1693	22	med_exam
# 46	1731	1733	今天	time
# 46	1743	1745	今天	time
# 46	1746	1752	早上36.2	time
# 46	1771	1775	36.2	med_exam
# 46	1783	1787	36.8	med_exam
# 46	1810	1814	37.5	med_exam
# 46	1827	1831	37.5	med_exam
# 46	1881	1885	37.5	med_exam
# 46	2356	2358	一天	time
# 46	2484	2489	兩三個禮拜	time
# 46	2897	2899	今天	time
# 46	2961	2963	10	med_exam
# 46	2967	2969	10	med_exam
# 46	3002	3005	134	med_exam
# 46	3009	3012	134	med_exam
# 46	3027	3029	10	med_exam
# 46	3043	3045	10	med_exam
# 46	3076	3078	10	med_exam
# 46	3122	3125	136	med_exam
# 46	3330	3332	10	med_exam
# 46	3376	3378	10	med_exam
# 46	3393	3395	10	med_exam
# 46	3802	3804	28	med_exam
# 46	3815	3818	28天	time
# 46	3819	3822	28天	time
# 46	3857	3861	兩個禮拜	time
# 46	3870	3874	兩個禮拜	time
# 46	3889	3893	兩個禮拜	time
# 46	3922	3925	上禮拜	time
# 46	4003	4007	兩個禮拜	time
# 46	4029	4033	下下禮拜	time
# 46	4277	4279	四週	time
# 46	4366	4368	四週	time
# 46	4382	4384	兩週	time
# 47	203	205	今天	time
# 47	206	208	12	time
# 47	215	217	12	time
# 47	303	306	林醫師	name
# 47	661	663	三天	time
# 47	716	718	33	money
# 47	741	744	515	med_exam
# 47	745	748	433	med_exam
# 47	749	752	124	med_exam
# 47	753	755	今天	time
# 47	818	821	4.3	med_exam
# 47	841	845	7500	med_exam
# 47	854	858	53萬9	money
# 47	865	868	5萬2	med_exam
# 47	890	892	今天	time
# 47	961	965	下個禮拜	time
# 47	1122	1123	G	profession
# 47	1188	1191	阿里山	location
# 47	1219	1222	阿里山	name
# 47	1257	1260	阿里山	name
# 47	1781	1785	下下禮拜	time
# 47	1909	1913	鉤端螺旋	name
# 47	1991	1995	鉤端螺旋	name
# 47	2184	2186	今天	time
# 47	2271	2274	789	time
# 47	2280	2282	小萱	name
# 48	6	11	5889小	money
# 48	13	15	小明	name
# 48	331	334	189	med_exam
# 48	335	338	189	med_exam
# 48	360	363	189	med_exam
# 48	401	404	166	med_exam
# 48	407	410	189	med_exam
# 48	421	424	166	med_exam
# 48	428	431	166	med_exam
# 48	441	444	217	time
# 48	455	458	200	money
# 48	463	466	225	med_exam
# 48	647	650	兩個月	time
# 48	655	658	兩個月	time
# 48	659	662	兩個月	time
# 48	839	841	65	med_exam
# 48	847	849	小明	name
# 48	902	904	一半	time
# 48	1072	1076	六個小時	time
# 48	1410	1415	25000	money
# 48	1428	1433	25000	money
# 48	1437	1440	300	money
# 48	1448	1452	3000	money
# 48	1486	1491	25000	money
# 48	1492	1494	25	med_exam
# 48	1536	1538	43	med_exam
# 48	1729	1732	淤清淤	profession
# 49	3	5	今天	time
# 49	14	16	爸爸	family
# 49	50	52	叔叔	name
# 49	78	80	學系	location
# 49	91	93	小美	name
# 49	128	132	10號拍	time
# 49	153	158	9月10號	time
# 49	160	162	小美	name
# 49	335	337	36	med_exam
# 49	342	344	36	med_exam
# 49	349	351	36	med_exam
# 49	352	356	36.9	time
# 49	357	361	36.7	med_exam
# 49	362	366	36.6	med_exam
# 49	840	844	45分鐘	time
# 49	913	917	30分鐘	time
# 49	961	963	小明	name
# 49	986	989	禮拜三	time
# 49	1169	1171	今天	time
# 49	1208	1211	禮拜一	time
# 49	1212	1214	早上	time
# 49	1282	1284	今天	time
# 49	1294	1296	今天	time
# 49	1297	1299	下午	time
# 49	1340	1343	禮拜一	time
# 49	1344	1346	早上	time
# 49	1352	1355	禮拜一	time
# 49	1356	1358	早上	time
# 49	1367	1370	俊教授	profession
# 49	1477	1480	SSA	name
# 49	1728	1731	ANA	time
# 49	2058	2060	台北	location
# 49	2065	2067	高雄	location
# 49	2082	2084	中山	location
# 49	2121	2123	學校	location
# 49	2849	2851	台北	location
# 49	2928	2930	小美	name
# 49	2943	2946	禮拜一	time
# 49	3049	3053	9月8號	time
# 49	3330	3333	許醫師	name
# 49	3338	3341	許醫師	name
# 49	3781	3783	三嬸	family
# 49	3784	3786	兒子	family
# 49	3800	3802	三嬸	name
# 49	3886	3888	三嬸	name
# 49	3900	3902	三嬸	time
# 49	3938	3942	姑的兒子	profession
# 49	3946	3948	姑姑	family
# 49	3949	3951	兒子	family
# 49	4033	4035	媽媽	location
# 49	4168	4171	禮拜一	time
# 49	4520	4522	榮總	location
# 49	4534	4536	台大	location
# 49	4541	4543	台大	location
# 49	4547	4549	台大	location
# 49	4609	4611	兩天	time
# 49	4778	4780	小美	name
# 50	13	15	奇美	location
# 50	82	85	禮拜六	time
# 50	125	128	禮拜天	time
# 50	129	133	7月17	time
# 50	138	140	前天	time
# 50	144	146	前天	time
# 50	151	153	前天	time
# 50	200	202	38	time
# 50	204	206	38	time
# 50	208	210	30	med_exam
# 50	212	216	38.6	med_exam
# 50	217	221	38.7	med_exam
# 50	325	329	6月25	time
# 50	334	336	昨天	time
# 50	449	451	今天	time
# 50	721	725	36.9	med_exam
# 50	729	733	36.9	med_exam
# 50	1201	1205	11.幾	med_exam
# 50	1209	1212	11.	med_exam
# 50	1224	1228	11.幾	med_exam
# 50	1290	1293	11號	time
# 50	1455	1457	禮拜	time
# 50	1459	1462	禮拜五	time
# 50	2028	2032	27.7	med_exam
# 50	3286	3288	奇美	name
# 50	3573	3577	下個禮拜	time
# 51	25	28	第三週	time
# 51	133	136	第三週	time
# 51	170	172	奇美	name
# 51	232	235	吳醫師	name
# 51	625	627	奇美	name
# 51	1263	1266	1月份	time
# 51	1283	1286	1月份	time
# 51	1523	1528	1月16號	time
# 51	1535	1540	1月16號	time
# 51	1545	1547	1月	time
# 51	1558	1563	1月16號	time
# 51	1674	1678	恍惚半年	time
# 51	2039	2043	三個禮拜	time
# 51	2051	2056	第三個禮拜	time
# 51	2061	2066	前兩個禮拜	time
# 51	2093	2098	第三個禮拜	time
# 51	2145	2147	趴趴	name
# 51	2336	2338	4週	time
# 51	2391	2394	吳醫師	name
# 51	2501	2502	三	location
# 51	2503	2505	美餒	profession
# 51	2506	2507	三	location
# 51	2866	2870	65公斤	med_exam
# 51	2882	2886	54公斤	med_exam
# 51	3289	3292	上禮拜	time
# 51	3395	3397	奇美	name
# 51	3460	3462	扶助	name
# 51	3796	3798	54	med_exam
# 51	3802	3804	58	med_exam
# 51	3814	3816	58	med_exam
# 51	3825	3827	58	med_exam
# 51	3915	3918	一個月	time
# 51	3923	3929	一個月又三週	time
# 51	3939	3941	三週	time
# 51	3945	3948	一個月	time
# 51	3949	3951	三週	time
# 51	3962	3965	一個月	time
# 51	3967	3969	三週	time
# 51	4034	4037	22萬	money
# 51	4098	4101	王牌組	name
# 51	4153	4155	王牌	name
# 51	4437	4439	兩週	time
# 51	4441	4444	第三週	time
# 51	4480	4483	第三週	time
# 51	4495	4498	第三週	time
# 51	4513	4515	三週	time
# 51	4517	4520	上一週	time
# 51	4552	4556	三個禮拜	time
# 51	4566	4570	兩個禮拜	time
# 51	4573	4577	兩個禮拜	time
# 51	4610	4614	一個禮拜	time
# 51	4779	4781	學校	location
# 51	4815	4819	一個禮拜	time
# 51	4822	4826	一個禮拜	time
# 51	4828	4832	10公斤	time
# 51	4847	4850	66公	med_exam
# 51	4858	4861	66公	med_exam
# 51	5188	5191	軟趴趴	profession
# 51	5574	5581	2020年5月	time
# 51	5852	5854	四天	time
# 51	5856	5858	五天	time
# 52	101	104	330	med_exam
# 52	176	181	15000	money
# 52	195	199	3200	money
# 52	203	207	3200	money
# 52	262	266	10.7	med_exam
# 52	289	290	8	med_exam
# 52	294	299	10.7幾	med_exam
# 52	332	336	兩個禮拜	time
# 52	397	402	兩個禮拜內	time
# 52	526	529	林醫師	name
# 52	532	535	780	med_exam
# 52	541	544	林醫師	name
# 52	545	548	780	med_exam
# 52	582	585	450	med_exam
# 52	812	815	450	med_exam
# 52	816	819	450	money
# 52	1086	1087	陳	name
# 52	1089	1092	陳老師	name
# 52	1149	1151	明明	name
# 52	1164	1169	7月15號	time
# 52	1221	1226	7月28號	time
# 52	1271	1273	小美	name
# 52	1276	1279	陳老師	name
# 52	1391	1395	兩個禮拜	time
# 52	1409	1413	一個禮拜	time
# 52	1416	1420	一個禮拜	time
# 52	1441	1445	100塊	money
# 52	1587	1592	8月20號	time
# 52	1602	1607	8月20號	time
# 53	77	79	槌子	family
# 53	114	118	兩個禮拜	time
# 53	337	341	兩個禮拜	time
# 53	409	413	十月二號	time
# 53	439	444	六百七十九	med_exam
# 53	526	528	台南	location
# 53	529	531	奇美	location
# 53	538	540	奇美	location
# 53	650	653	一千二	money
# 54	550	552	超市	location
# 54	567	573	十二月二十二	time
# 55	128	131	一個月	time
# 55	602	605	一個月	time
# 55	738	740	早上	time
# 55	756	758	一天	time
# 55	830	832	今天	time
# 55	835	837	今天	time
# 55	908	909	汽	location
# 55	1043	1045	去年	time
# 55	1063	1065	去年	time
# 55	1072	1074	今年	time
# 55	1104	1106	今年	time
# 55	1109	1112	五月中	time
# 55	1266	1268	一年	time
# 56	28	31	星期三	time
# 56	1528	1530	榮總	location
# 56	1691	1693	爸爸	family
# 56	2152	2157	九月二十五	time
# 56	2166	2169	兩個月	time
# 56	2175	2179	十月一號	time
# 56	2208	2212	十五禮拜	time
# 56	2216	2219	禮拜四	time
# 56	2220	2222	下午	time
# 56	2300	2302	九天	time
# 56	2307	2310	十幾天	time
# 57	60	64	九個小時	time
# 57	172	175	前一天	time
# 57	183	186	前兩天	time
# 57	258	260	廁所	name
# 57	279	281	一年	time
# 57	416	419	八十五	med_exam
# 57	423	426	八十五	med_exam
# 57	441	444	一七五	med_exam
# 57	519	522	三、三	time
# 57	523	525	四年	time
# 57	529	533	三、四年	time
# 57	746	750	三個禮拜	time
# 57	753	758	四個禮拜前	time
# 57	798	802	三個禮拜	time
# 57	889	892	一九二	med_exam
# 57	1066	1069	一百三	med_exam
# 57	1306	1309	五十歲	time
# 57	1777	1779	嘉芳	location
# 57	1800	1803	下禮拜	time
# 57	1813	1816	五個月	time
# 57	1850	1853	五個月	time
# 57	1859	1862	五個月	time
# 57	1876	1879	五個月	time
# 57	1909	1912	五個月	time
# 57	2017	2019	小叔	name
# 57	2024	2026	小叔	name
# 57	2028	2030	爺爺	family
# 57	2081	2084	十二月	time
# 58	6	11	56783	money
# 58	212	215	禮拜幾	time
# 58	217	220	禮拜四	time
# 58	232	234	早上	time
# 58	472	474	小便	name
# 58	767	770	三個月	time
# 59	4	7	禮拜天	time
# 59	8	10	中午	time
# 59	12	15	禮拜一	time
# 59	21	23	中午	time
# 59	30	32	禮拜	time
# 59	159	161	今天	time
# 59	164	167	禮拜一	time
# 59	169	172	禮拜二	time
# 59	442	444	昨天	time
# 59	460	463	巫醫師	name
# 59	491	494	林醫師	name
# 59	615	618	王醫師	name
# 59	625	627	陽明	name
# 59	702	704	今天	time
# 59	726	728	昨天	time
# 59	737	739	昨天	time
# 59	750	752	昨天	time
# 59	753	755	早上	time
# 59	894	896	三天	time
# 59	907	909	三天	time
# 59	1027	1030	王醫師	name
# 59	1043	1045	今天	time
# 59	1124	1126	台大	location
# 59	1261	1264	下禮拜	time
# 59	1271	1274	下禮拜	time
# 59	1302	1305	楊醫師	name
# 59	1362	1364	急診	location
# 59	1379	1381	急診	location
# 59	1382	1384	半夜	time
# 59	1692	1694	急診	location
# 59	1917	1919	台大	location
# 59	1941	1945	陽明醫院	name
# 59	2052	2055	12樓	money
# 59	2114	2116	今天	time
# 60	96	98	嘉義	location
# 60	104	106	嘉義	location
# 60	107	109	台南	location
# 60	363	367	去兩個月	time
# 60	426	429	這個月	time
# 60	515	520	5、6、7	time
# 60	521	524	8月底	time
# 60	547	550	8月底	time
# 60	685	687	今天	time
# 60	1177	1180	8月7	time
# 60	1184	1187	8月7	time
# 60	1196	1199	禮拜三	time
# 60	1200	1202	下午	time
# 60	1206	1209	禮拜三	time
# 60	1210	1212	下午	time
# 60	1222	1224	早上	time
# 60	1228	1231	禮拜四	time
# 60	1234	1237	禮拜四	time
# 60	1238	1240	早上	time
# 60	1244	1247	禮拜五	time
# 60	1248	1250	早上	time
# 60	1259	1262	禮拜五	time
# 60	1263	1265	早上	time
# 60	1271	1273	早上	time
# 60	1312	1314	今天	time
# 60	1315	1319	9點45	time
# 60	1339	1342	禮拜三	time
# 60	1349	1352	禮拜三	time
# 60	1367	1369	早上	time
# 60	1407	1410	禮拜五	time
# 60	1411	1413	早上	time
# 60	1423	1426	8月7	time
# 60	1430	1433	8月7	time
# 60	1498	1501	李小姐	name
# 60	1540	1543	5月份	time
# 60	1549	1551	5月	time
# 60	1554	1556	35	time
# 60	1577	1580	這個月	time
# 60	1718	1723	6月15號	time
# 60	1801	1802	喂	name
# 60	1815	1818	李小龍	name
# 60	1822	1824	李小	name
# 60	1875	1880	6月15號	time
# 60	1898	1903	6月15號	time
# 60	1986	1989	台北市	location
# 60	2008	2012	9654	med_exam
# 60	2028	2030	85	time
# 60	2034	2038	1996	time
# 60	2043	2047	1996	med_exam
# 60	2053	2058	5月21號	time
# 60	2064	2068	5月21	time
# 60	2084	2087	6月底	time
# 60	2091	2093	35	med_exam
# 60	2105	2108	15號	time
# 60	2130	2135	6月15號	time
# 60	2146	2151	6月15號	time
# 60	2192	2197	6月15號	time
# 60	2220	2225	6月15號	time
# 60	2262	2267	6月15號	time
# 60	2272	2274	5號	time
# 60	2283	2288	6月15號	time
# 60	2292	2297	6月15號	time
# 60	2443	2446	5月多	time
# 60	2456	2461	6月15號	time
# 60	2480	2482	掰掰	name
# 60	2497	2499	5月	time
# 60	2503	2505	35	med_exam
# 60	2509	2511	4月	time
# 60	2581	2584	兩三年	time
# 60	2599	2602	兩三年	time
# 61	540	544	第二個月	time
# 61	651	655	第一個月	time
# 61	919	922	下個月	time
# 61	978	983	前兩個小時	time
# 61	1143	1145	八點	time
# 61	2022	2028	11月12號	time
# 61	2030	2033	兩個月	time
# 61	2038	2043	11月12	time
# 61	2051	2054	禮拜三	time
# 61	2055	2057	早上	time
# 61	2083	2087	第一個月	time
# 61	2129	2135	11月12號	time
# 61	2136	2138	平日	time
# 61	2213	2216	十幾號	time
# 61	2280	2282	台北	location
# 61	2293	2295	台北	location
# 61	2343	2346	五月中	time
# 61	2388	2391	三百年	time
# 61	2421	2426	11月12	time
# 62	50	53	這個月	time
# 62	60	62	3個	time
# 62	75	76	3	med_exam
# 62	83	85	3組	med_exam
# 62	300	302	一年	time
# 62	550	552	兩個	time
# 62	567	569	矛盾	name
# 62	741	744	小猶豫	name
# 62	906	911	11月29	time
# 62	915	918	禮拜五	time
# 62	919	921	下午	time
# 63	188	190	兩組	location
# 63	343	347	上上個月	time
# 63	353	356	下個月	time
# 64	4	6	今天	time
# 64	9	12	兩個月	time
# 64	746	749	兩個月	time
# 64	782	785	兩個月	time
# 64	801	804	下個月	time
# 64	981	985	9403	money
# 64	1005	1008	第三年	time
# 64	1057	1059	兩年	time
# 64	1117	1119	泰國	location
# 65	71	74	這個月	time
# 65	205	208	上個月	time
# 65	267	269	籃球	location
# 65	1277	1279	1號	time
# 65	1475	1477	一號	time
# 65	1483	1485	0號	time
# 65	1573	1575	69	time
# 66	253	255	前天	time
# 66	269	271	前天	time
# 67	34	37	許小姐	name
# 67	61	64	許小姐	name
# 67	326	328	前後	time
# 67	330	333	半年多	time
# 67	678	681	王醫師	name
# 67	881	884	王醫師	name
# 67	895	896	3	time
# 67	947	949	今天	time
# 67	960	962	今天	time
# 67	1081	1084	下個月	time
# 67	1113	1116	三個月	time
# 67	1204	1207	禮拜三	time
# 67	1208	1211	禮拜五	time
# 67	1223	1226	王醫師	name
# 67	1236	1239	王醫師	name
# 67	1240	1243	禮拜三	time
# 67	1244	1246	下午	time
# 67	1247	1250	禮拜五	time
# 67	1251	1253	早上	time
# 67	1290	1293	禮拜二	time
# 67	1300	1303	禮拜二	time
# 67	1310	1312	隔週	time
# 67	1313	1316	禮拜二	time
# 67	1333	1336	28天	time
# 67	1366	1369	禮拜三	time
# 67	1389	1392	禮拜三	time
# 67	1412	1415	禮拜五	time
# 67	1419	1422	禮拜五	time
# 67	1449	1451	下週	time
# 67	1452	1455	禮拜五	time
# 67	1464	1467	28天	time
# 67	1478	1480	28	med_exam
# 67	1547	1549	中央	name
# 67	1556	1560	跨一個月	time
# 67	1572	1576	跨一個月	time
# 68	9	13	這一個月	time
# 68	31	33	今天	time
# 68	144	147	這個月	time
# 68	683	685	早上	time
# 68	730	733	下個月	time
# 69	267	269	姐姐	family
# 69	287	288	姊	family
# 69	362	365	這個月	time
# 69	1057	1059	兩天	time
# 69	1063	1066	前一天	time
# 69	1239	1242	前一天	time
# 69	1248	1250	今天	time
# 69	1251	1255	9月10	time
# 69	1267	1270	9月9	time
# 69	1271	1275	9月11	time
# 69	1276	1278	12	time
# 69	1320	1324	5、6點	time
# 69	1337	1339	6點	time
# 69	1342	1344	6點	time
# 69	1390	1394	兩個小時	time
# 69	1408	1410	1號	time
# 69	1529	1532	前一天	time
# 69	1563	1568	2到24小	time
# 69	1597	1601	9月8號	time
# 69	1609	1611	6點	time
# 69	1634	1636	7點	time
# 69	1639	1641	4點	time
# 69	1800	1803	前一天	time
# 69	1834	1836	三天	time

# %%
output_path='output/roberta_BiLSTM_CRF_len_32_epo_20.tsv'
with open(output_path, 'w', encoding='utf-8') as f:
    f.write(output)
