# %%
import pandas as pd

# %%
ensemble_df = pd.DataFrame(columns=['article_id', 'start_position', 'end_position', 'entity_text', 'entity_type', 'source'])
ensemble_df
# Out:
# Empty DataFrame
# Columns: [article_id, start_position, end_position, entity_text, entity_type, source]
# Index: []

# %%
bert_df = pd.read_csv('/home/Danny/AI-CUP-2020/danny/bert/output/bert-chinese_epoch_512_batch_1024.tsv', sep='\t')
bert_df['source'] = 'bert'
bert_df
# Out:
#       article_id  start_position  end_position entity_text entity_type source
# 0              0              36            38          年底        time   bert
# 1              0             113           115          今天        time   bert
# 2              0             198           200          新樓    location   bert
# 3              0             227           229          麻豆    location   bert
# 4              0             237           239          麻豆    location   bert
# ...          ...             ...           ...         ...         ...    ...
# 3095         158            1074          1076          今天        time   bert
# 3096         158            1082          1086        第三個月        time   bert
# 3097         158            1143          1145          今天        time   bert
# 3098         158            1199          1201          小安        name   bert
# 3099         158            1381          1390   124699678    med_exam   bert
#
# [3100 rows x 6 columns]

# %%
pd.unique(bert_df['entity_type'])
# Out:
# array(['time', 'location', 'med_exam', 'name', 'ID', 'money', 'contact',
#        'family', 'profession', 'education', 'organization'], dtype=object)

# %%
bert_df[bert_df['entity_type'] == 'time'].to_csv('output/time.tsv', sep='\t')
# Out:
#       article_id  start_position  end_position entity_text entity_type source
# 0              0              36            38          年底        time   bert
# 1              0             113           115          今天        time   bert
# 5              0             295           297          今年        time   bert
# 6              1              31            33          今天        time   bert
# 7              1              40            42          昨天        time   bert
# ...          ...             ...           ...         ...         ...    ...
# 3092         158             421           423          26        time   bert
# 3093         158             431           435        二十二十        time   bert
# 3095         158            1074          1076          今天        time   bert
# 3096         158            1082          1086        第三個月        time   bert
# 3097         158            1143          1145          今天        time   bert
#
# [2102 rows x 6 columns]

# %%
regular_expression_df = pd.read_csv('/home/Danny/AI-CUP-2020/regular_expression/regular_expression.tsv', sep='\t')
regular_expression_df
# Out:
#     article_id  start_position  end_position entity_text entity_type  \
# 0            9               7            17  E127388873          ID
# 1           13            1273          1283  E137354975          ID
# 2           35            1801          1811  R103846354          ID
# 3           36            1115          1125  E183745524          ID
# 4           38             766           776  0935642234     contact
# 5           40             499           509  E184666204          ID
# 6           44               6            16  R113566480          ID
# 7           46             384           394  0933625337     contact
# 8           49               8            18  R113993846          ID
# 9           51              20            30  R334666726          ID
# 10          63               6            16  R234526780          ID
# 11          65            2301          2311  F178290737          ID
# 12          90            1525          1535  R223640298          ID
# 13          91               3            13  A184058370          ID
# 14          92            1423          1433  A148390275          ID
# 15          93             802           812  E128739467          ID
# 16         103             633           643  S137465537          ID
# 17         121             996          1006  A289370198          ID
# 18         126             743           753  R147380478          ID
# 19         142              15            25  R100382694          ID
# 20         143             808           818  0927773645     contact
# 21         146               6            16  E189370256          ID
# 22         158            1380          1390  A124699678          ID
#
#                 source
# 0   regular_expression
# 1   regular_expression
# 2   regular_expression
# 3   regular_expression
# 4   regular_expression
# 5   regular_expression
# 6   regular_expression
# 7   regular_expression
# 8   regular_expression
# 9   regular_expression
# 10  regular_expression
# 11  regular_expression
# 12  regular_expression
# 13  regular_expression
# 14  regular_expression
# 15  regular_expression
# 16  regular_expression
# 17  regular_expression
# 18  regular_expression
# 19  regular_expression
# 20  regular_expression
# 21  regular_expression
# 22  regular_expression

# %%
dictionary_df = pd.read_csv('/home/Danny/AI-CUP-2020/dictionary/dictionary.tsv', sep='\t')
dictionary_df
# Out:
#     article_id  start_position  end_position entity_text entity_type  \
# 0           62            1400          1402          臉書     contact
# 1           50            2410          2414        LINE     contact
# 2          104             521           525        LINE     contact
# 3          115            1252          1256        LINE     contact
# 4          116            1301          1305        LINE     contact
# 5          133             322           326        LINE     contact
# 6          133            1012          1016        LINE     contact
# 7          136             465           469        LINE     contact
# 8          136             528           532        LINE     contact
# 9          136             776           780        LINE     contact
# 10         138            1444          1448        LINE     contact
# 11         138            1563          1567        LINE     contact
# 12         142             486           490        LINE     contact
# 13         157            2923          2927        LINE     contact
# 14         132            1420          1424        ＬＩＮＥ     contact
# 15         155            2549          2553        ＬＩＮＥ     contact
# 16          24             425           429        line     contact
# 17          24             465           469        line     contact
# 18          64             925           929        line     contact
# 19         122            1844          1848        line     contact
# 20         127             709           713        line     contact
# 21         131             219           223        line     contact
# 22         131             349           353        line     contact
# 23         131            1154          1158        line     contact
# 24         148            1092          1096        line     contact
# 25         124             466           470        Line     contact
# 26         137            1399          1403        Line     contact
# 27         142             457           461        MAIL     contact
# 28         142             456           461       EMAIL     contact
#
#                      source
# 0   dictionary_ground_truth
# 1   dictionary_ground_truth
# 2   dictionary_ground_truth
# 3   dictionary_ground_truth
# 4   dictionary_ground_truth
# 5   dictionary_ground_truth
# 6   dictionary_ground_truth
# 7   dictionary_ground_truth
# 8   dictionary_ground_truth
# 9   dictionary_ground_truth
# 10  dictionary_ground_truth
# 11  dictionary_ground_truth
# 12  dictionary_ground_truth
# 13  dictionary_ground_truth
# 14  dictionary_ground_truth
# 15  dictionary_ground_truth
# 16  dictionary_ground_truth
# 17  dictionary_ground_truth
# 18  dictionary_ground_truth
# 19  dictionary_ground_truth
# 20  dictionary_ground_truth
# 21  dictionary_ground_truth
# 22  dictionary_ground_truth
# 23  dictionary_ground_truth
# 24  dictionary_ground_truth
# 25  dictionary_ground_truth
# 26  dictionary_ground_truth
# 27  dictionary_ground_truth
# 28  dictionary_ground_truth

# %%
ensemble_df = ensemble_df.append(bert_df, ignore_index=True)
ensemble_df = ensemble_df.append(regular_expression_df, ignore_index=True)
ensemble_df = ensemble_df.append(dictionary_df, ignore_index=True)
ensemble_df
# Out:
#      article_id start_position end_position entity_text entity_type  \
# 0             0             36           38          年底        time
# 1             0            113          115          今天        time
# 2             0            198          200          新樓    location
# 3             0            227          229          麻豆    location
# 4             0            237          239          麻豆    location
# ...         ...            ...          ...         ...         ...
# 3147        148           1092         1096        line     contact
# 3148        124            466          470        Line     contact
# 3149        137           1399         1403        Line     contact
# 3150        142            457          461        MAIL     contact
# 3151        142            456          461       EMAIL     contact
#
#                        source
# 0                        bert
# 1                        bert
# 2                        bert
# 3                        bert
# 4                        bert
# ...                       ...
# 3147  dictionary_ground_truth
# 3148  dictionary_ground_truth
# 3149  dictionary_ground_truth
# 3150  dictionary_ground_truth
# 3151  dictionary_ground_truth
#
# [3152 rows x 6 columns]

# %%
ensemble_df = ensemble_df.sort_values(by=['article_id', 'start_position'])
ensemble_df
# Out:
#      article_id start_position end_position entity_text entity_type  \
# 0             0             36           38          年底        time
# 1             0            113          115          今天        time
# 2             0            198          200          新樓    location
# 3             0            227          229          麻豆    location
# 4             0            237          239          麻豆    location
# ...         ...            ...          ...         ...         ...
# 3096        158           1082         1086        第三個月        time
# 3097        158           1143         1145          今天        time
# 3098        158           1199         1201          小安        name
# 3122        158           1380         1390  A124699678          ID
# 3099        158           1381         1390   124699678    med_exam
#
#                   source
# 0                   bert
# 1                   bert
# 2                   bert
# 3                   bert
# 4                   bert
# ...                  ...
# 3096                bert
# 3097                bert
# 3098                bert
# 3122  regular_expression
# 3099                bert
#
# [3152 rows x 6 columns]

# %%
ensemble_df[(ensemble_df['entity_type'] == 'contact') & (ensemble_df['source'] == 'bert')]
# Out:
#      article_id start_position end_position entity_text entity_type source
# 192           9              7           17  E127388873     contact   bert
# 218          10           1565         1572     DRLEEOP     contact   bert
# 303          13           1274         1283   137354975     contact   bert
# 668          36             11           18     CD41358     contact   bert
# 901          50           2415         2422     DRLINOP     contact   bert
# 902          51             20           30  R334666726     contact   bert
# 1109         62           1400         1402          臉書     contact   bert
# 1139         64            930          939   drawpeter     contact   bert
# 1732         88           1104         1112    ＮＥＧＡＴＩＶＥ     contact   bert
# 1772         90           1525         1535  R223640298     contact   bert
# 2002        103            633          643  S137465537     contact   bert
# 2008        104            526          532      CHENAD     contact   bert
# 2252        115            428          435     license     contact   bert
# 2269        116           1301         1305        LINE     contact   bert
# 2270        116           1307         1314     PREPEAT     contact   bert
# 2395        124            466          470        Line     contact   bert
# 2420        126            743          753  R147380478     contact   bert
# 2432        127            709          713        line     contact   bert
# 2484        131            219          223        line     contact   bert
# 2488        131            349          353        line     contact   bert
# 2507        131           1154         1158        line     contact   bert
# 2523        132           1420         1424        ＬＩＮＥ     contact   bert
# 2535        133            987          991        prep     contact   bert
# 2536        133           1012         1016        LINE     contact   bert
# 2552        135            710          714        mail     contact   bert
# 2567        136            465          469        LINE     contact   bert
# 2571        136            776          780        LINE     contact   bert
# 2586        137           1399         1403        Line     contact   bert
# 2609        138           1444         1448        LINE     contact   bert
# 2610        138           1563         1567        LINE     contact   bert
# 2676        142            486          490        LINE     contact   bert
# 2703        143            808          818  0927773645     contact   bert
# 2710        144           1364         1368        siri     contact   bert
# 2752        146              6           16  E189370256     contact   bert
# 2798        148           1109         1116     pwodumn     contact   bert
# 3062        157           2923         2927        LINE     contact   bert

# %%
ensemble_df[(ensemble_df['entity_type'] == 'ID') & (ensemble_df['source'] == 'bert')]
# Out:
#      article_id start_position end_position entity_text entity_type source
# 23            1            867          869          21          ID   bert
# 457          22            752          756        7382          ID   bert
# 838          45           3281         3286       23343          ID   bert
# 1493         80           1228         1230          25          ID   bert
# 2277        117            458          460          20          ID   bert

# %%
ensemble_df[(ensemble_df['entity_type'] == 'ID') & (ensemble_df['source'] == 'bert')].index
# Out:
# Int64Index([23, 457, 838, 1493, 2277], dtype='int64')

# %%
ensemble_df = ensemble_df.drop(ensemble_df[(ensemble_df['entity_type'] == 'ID') & (ensemble_df['source'] == 'bert')].index)
ensemble_df
# Out:
#      article_id start_position end_position entity_text entity_type  \
# 0             0             36           38          年底        time
# 1             0            113          115          今天        time
# 2             0            198          200          新樓    location
# 3             0            227          229          麻豆    location
# 4             0            237          239          麻豆    location
# ...         ...            ...          ...         ...         ...
# 3096        158           1082         1086        第三個月        time
# 3097        158           1143         1145          今天        time
# 3098        158           1199         1201          小安        name
# 3122        158           1380         1390  A124699678          ID
# 3099        158           1381         1390   124699678    med_exam
#
#                   source
# 0                   bert
# 1                   bert
# 2                   bert
# 3                   bert
# 4                   bert
# ...                  ...
# 3096                bert
# 3097                bert
# 3098                bert
# 3122  regular_expression
# 3099                bert
#
# [3147 rows x 6 columns]

# %%
ensemble_df[ensemble_df['entity_type'] == 'ID']
# Out:
#      article_id start_position end_position entity_text entity_type  \
# 3100          9              7           17  E127388873          ID
# 3101         13           1273         1283  E137354975          ID
# 3102         35           1801         1811  R103846354          ID
# 3103         36           1115         1125  E183745524          ID
# 3105         40            499          509  E184666204          ID
# 3106         44              6           16  R113566480          ID
# 3108         49              8           18  R113993846          ID
# 3109         51             20           30  R334666726          ID
# 3110         63              6           16  R234526780          ID
# 3111         65           2301         2311  F178290737          ID
# 3112         90           1525         1535  R223640298          ID
# 3113         91              3           13  A184058370          ID
# 3114         92           1423         1433  A148390275          ID
# 3115         93            802          812  E128739467          ID
# 3116        103            633          643  S137465537          ID
# 3117        121            996         1006  A289370198          ID
# 3118        126            743          753  R147380478          ID
# 3119        142             15           25  R100382694          ID
# 3121        146              6           16  E189370256          ID
# 3122        158           1380         1390  A124699678          ID
#
#                   source
# 3100  regular_expression
# 3101  regular_expression
# 3102  regular_expression
# 3103  regular_expression
# 3105  regular_expression
# 3106  regular_expression
# 3108  regular_expression
# 3109  regular_expression
# 3110  regular_expression
# 3111  regular_expression
# 3112  regular_expression
# 3113  regular_expression
# 3114  regular_expression
# 3115  regular_expression
# 3116  regular_expression
# 3117  regular_expression
# 3118  regular_expression
# 3119  regular_expression
# 3121  regular_expression
# 3122  regular_expression

# %%
ensemble_df = ensemble_df.drop(columns=['source'])
ensemble_df = ensemble_df.drop_duplicates()
ensemble_df.to_csv('ensemble.tsv', sep='\t', index=False)
